# %% [markdown]
# # Task 0: The Library of Babel
#
# Building a dataset with three classes:
# - **Class 1**: Human text (Austen + Gaskell novels)
# - **Class 2**: AI text on same topics (neutral style)
# - **Class 3**: AI text on same topics (mimicking author styles)
#
# Goal: Make authorship the key differentiator, not topic. All paragraphs are 100-200 words.

# %% [markdown]
# ## Notebook Overview
#
# This notebook generates the dataset for Task 0. It's organized into:
#
# 1. **Setup** - Imports, paths, and configuration
# 2. **Class 1 (Human)** - Extract and process text from novels
# 3. **Topic Extraction** - Identify shared themes
# 4. **Class 2 (AI-Neutral)** - Generate paragraphs without style mimicry
# 5. **Class 3 (AI-Styled)** - Generate paragraphs mimicking author styles
#
# **Output Files:**
# - `class1_human_data_try1.json`
# - `class2_ai_data_try1.json`
# - `class3_ai_data_try1.json`

# %% [markdown]
# ## Step 1: Choose Authors
#
# Using Jane Austen and Elizabeth Gaskell because:
# - Both write about similar topics (family, class, morality, domestic life)
# - Different styles (Austen: ironic, restrained; Gaskell: emotional, descriptive)
# - Same time period and language (19th-century British English)
#
# This keeps topic constant while varying style.

# %% [markdown]
# ### Why These Specific Authors?
#
# Could have used other author pairs (e.g., Dickens + Thackeray, Brontë sisters). Chose Austen + Gaskell because:
# 1. **Topic overlap** - Both write about domestic life, marriage, class
# 2. **Different styles** - Austen is ironic/restrained, Gaskell is emotional/descriptive
# 3. **Same era** - Both 19th century, similar language baseline
# 4. **Availability** - Clean Project Gutenberg texts available

# %% [markdown]
# ## Step 2: Source Material
#
# Three novels per author from Project Gutenberg:
#
# **Jane Austen**
# - Pride and Prejudice
# - Sense and Sensibility
# - Emma
#
# **Elizabeth Gaskell**
# - North and South
# - Mary Barton
# - Cranford

# %% [markdown]
# ## Step 3: Preprocessing Pipeline
#
# 1. Parse HTML and remove Project Gutenberg boilerplate
# 2. Normalize text (fix drop caps, remove page markers)
# 3. Clean paragraphs
# 4. Re-chunk into 100-200 word windows

# %% [markdown]
# ## Imports

# %%
import os
import json
import time
import uuid
import re
import hashlib
import random
import numpy as np
from pathlib import Path
from bs4 import BeautifulSoup
from itertools import product
from google import genai

# %% [markdown]
# All required libraries are imported here at the top for clarity. If running this notebook on a fresh environment, install:
# ```
# pip install beautifulsoup4 numpy google-generativeai nltk
# ```

# %% [markdown]
# ## Setup Paths
#
# This will work when cloned from GitHub. It checks if we're in the project root or need to go into PreCog_Task folder.

# %%
PROJECT_ROOT = Path.cwd()

# If data folder doesn't exist in current directory, try PreCog_Task subfolder
if not (PROJECT_ROOT / "data").exists():
    if (PROJECT_ROOT / "PreCog_Task" / "data").exists():
        PROJECT_ROOT = PROJECT_ROOT / "PreCog_Task"
    else:
        raise FileNotFoundError("Cannot find data folder. Make sure you're in the right directory.")

print(f"Using project root: {PROJECT_ROOT}")
# Out:
# Using project root: /home/venya-velmurugan/Documents/PreCog_Task

# %%
list((PROJECT_ROOT / "data" / "raw" ).iterdir())
# Out:
# [PosixPath('/home/venya-velmurugan/Documents/PreCog_Task/data/raw/austen'),
#  PosixPath('/home/venya-velmurugan/Documents/PreCog_Task/data/raw/gaskell')]

# %%
BOOKS = {
    "austen": {
        "pride_and_prejudice": PROJECT_ROOT / "data/raw/austen/pride_and_prejudice.html",
        "emma": PROJECT_ROOT / "data/raw/austen/emma.html",
        "sense_and_sensibility": PROJECT_ROOT / "data/raw/austen/sense_and_sensibility.html",
    },
    "gaskell": {
        "cranford": PROJECT_ROOT / "data/raw/gaskell/cranford.html",
        "mary_barton": PROJECT_ROOT / "data/raw/gaskell/mary_barton.html",
        "north_and_south": PROJECT_ROOT / "data/raw/gaskell/north_and_south.html",
    },
}

# %% [markdown]
# ## Text Cleaning Functions

# %% [markdown]
# These utility functions handle common text normalization issues in Project Gutenberg files:
# - Drop caps (e.g., "I T is" → "It is")
# - Page markers (e.g., {45}, {xxiii})
# - Formatting artifacts
# - Remove chapter headings
# - Remove licenses
# - Remove "The end" and other such markers

# %%
def normalize_leading_split_word(text):
    return re.sub(
        r"^([A-Z])\s+([A-Z])\s+",
        lambda m: m.group(1) + m.group(2).lower() + " ",
        text
    )

def remove_page_markers(text):
    
    return re.sub(
        r"\{\s*[0-9ivxlcdm]+\s*\}",
        "",
        text,
        flags=re.IGNORECASE
    )

# %%
def merge_dropcaps(blocks):
    merged = []
    i = 0

    while i < len(blocks):
        curr = blocks[i].strip()

        if len(curr) == 1 and curr.isalpha() and i + 1 < len(blocks):
            nxt = blocks[i + 1].lstrip()
            m = re.match(r"^([A-Z])\s+(.*)", nxt)
            if m:
                merged.append(curr + m.group(1).lower() + " " + m.group(2))
            else:
                merged.append(curr + nxt)
            i += 2
        else:
            merged.append(curr)
            i += 1

    return merged

# %%
def extract_blocks(soup):
    blocks = []
    for tag in soup.find_all(["p", "h1", "h2", "h3"]):
        text = tag.get_text(" ", strip=True)
        if text:
            blocks.append(text)
            
    return blocks


def is_true_chapter_heading(text):
    t = text.strip()
    return bool(
        re.match(
            r"^(CHAPTER|Chapter)\s+([IVXLCDM]+|\d+)\b",
            t
        )
    )

# %%
def is_gutenberg_license(text):
    t = text.strip().upper()
    return (
        "PROJECT GUTENBERG LICENSE" in t
        or "THE FULL PROJECT GUTENBERG LICENSE" in t
    )

# %%
def is_explicit_end_marker(text):
    t = text.strip().upper()
    return (
        t == "THE END."
        or t == "THE END"
        or t.startswith("THE END.")
        or "*** END OF THE PROJECT GUTENBERG EBOOK" in t
        or "WALTER SCOTT PRESS" in t
    )

# %% [markdown]
# ## Load and Clean Books

# %%
BOOK_PATH = PROJECT_ROOT / "data" / "raw" / "austen" / "pride_and_prejudice.html"

with open(BOOK_PATH, "r", encoding="utf-8") as f:
    soup = BeautifulSoup(f, "html.parser")

# %%
raw_paragraphs = [p.get_text().strip() for p in soup.find_all("p")]
len(raw_paragraphs), raw_paragraphs[:5]
# Out:
# (2146,
#  ['Title: Pride and Prejudice',
#   'Author: Jane Austen',
#   'Release date: June 1, 1998 [eBook #1342]\n                Most recently updated: September 22, 2025',
#   'Language: English',
#   'Credits: Chuck Greif and the Online Distributed Proofreading Team at http://www.pgdp.net (This file was produced from images available at The Internet Archive)'])

# %% [markdown]
# ### Test the Cleaning Pipeline
#
# Load one book and verify the cleaning works correctly.

# %% [markdown]
# ## Remove Project Gutenberg Boilerplate
#
# Project Gutenberg files have headers, legal notices, and end markers that need to be removed.

# %%
def clean_gutenberg_html(file_path):
    with open(file_path, "r", encoding="utf-8") as f:
        soup = BeautifulSoup(f, "html.parser")

    for tag in soup(["script", "style"]):
        tag.decompose()

    blocks = extract_blocks(soup)
    blocks = merge_dropcaps(blocks)

    start_idx = None
    for i, block in enumerate(blocks):
        if is_true_chapter_heading(block):
            start_idx = i + 1
            break

    if start_idx is None:
        raise ValueError("No chapter heading found - HTML structure unexpected")

    end_idx = len(blocks)
    for i, block in enumerate(blocks):
        if "END OF THE PROJECT GUTENBERG EBOOK" in block.upper():
            end_idx = i
            break

    story = blocks[start_idx:end_idx]

    final_paragraphs = []
    for i, p in enumerate(story):
        if i == 0:
            final_paragraphs.append(p)
        elif len(p.split()) > 10 and not is_true_chapter_heading(p):
            final_paragraphs.append(p)

    final_paragraphs = [
        normalize_leading_split_word(remove_page_markers(p)).strip()
        for p in final_paragraphs
    ]

    while final_paragraphs and is_explicit_end_marker(final_paragraphs[-1]):
        final_paragraphs.pop()

    return final_paragraphs


clean_data = clean_gutenberg_html(BOOK_PATH)

# %% [markdown]
# ### Main Cleaning Function
#
# This does the heavy lifting:
# 1. Parse HTML with BeautifulSoup
# 2. Extract text blocks (paragraphs and headings)
# 3. Find where the actual story starts (first chapter heading)
# 4. Find where it ends (Project Gutenberg end marker)
# 5. Filter out non-narrative content (chapter headings, short fragments)
# 6. Apply text normalization

# %%
sample = clean_gutenberg_html(BOOKS["austen"]["pride_and_prejudice"])

print("--- FIRST PARAGRAPH ---")
print(sample[0])

print("\n--- LAST PARAGRAPH ---")
print(sample[-1])
# Out:
# --- FIRST PARAGRAPH ---
# It is a truth universally acknowledged, that a single man in possession
# of a good fortune must be in want of a wife.
#
# --- LAST PARAGRAPH ---
# With the Gardiners they were always on the most intimate terms. Darcy,
# as well as Elizabeth, really loved them; and they were both ever
# sensible of the warmest gratitude towards the persons who, by bringing
# her into Derbyshire, had been the means of uniting them.

# %% [markdown]
# ### Process All Books
#
# This cell loads and cleans all 6 books (3 per author).

# %%
all_clean_data = {}

for author, books in BOOKS.items():
    for book, path in books.items():
        paras = clean_gutenberg_html(path)
        all_clean_data[(author, book)] = paras
        print(f"{author}/{book}: {len(paras)} paragraphs")
# Out:
# austen/pride_and_prejudice: 1832 paragraphs
# austen/emma: 2115 paragraphs
# austen/sense_and_sensibility: 1592 paragraphs
# gaskell/cranford: 611 paragraphs
# gaskell/mary_barton: 2527 paragraphs
# gaskell/north_and_south: 2629 paragraphs

# %%
for (author, book), paras in all_clean_data.items():
    print(f"\n{author.upper()} - {book}")
    print("FIRST:", paras[0])
    print("LAST :", paras[-1])
# Out:
# AUSTEN - pride_and_prejudice
# FIRST: It is a truth universally acknowledged, that a single man in possession
# of a good fortune must be in want of a wife.
# LAST : With the Gardiners they were always on the most intimate terms. Darcy,
# as well as Elizabeth, really loved them; and they were both ever
# sensible of the warmest gratitude towards the persons who, by bringing
# her into Derbyshire, had been the means of uniting them.
#
# AUSTEN - emma
# FIRST: Emma Woodhouse, handsome, clever, and rich, with a comfortable home and happy
# disposition, seemed to unite some of the best blessings of existence; and had
# lived nearly twenty-one years in the world with very little to distress or vex
# her.
# LAST : The wedding was very much like other weddings, where the parties have no taste
# for finery or parade; and Mrs. Elton, from the particulars detailed by her
# husband, thought it all extremely shabby, and very inferior to her
# own.—“Very little white satin, very few lace veils; a most pitiful
# business!—Selina would stare when she heard of it.”—But, in
# spite of these deficiencies, the wishes, the hopes, the confidence, the
# predictions of the small band of true friends who witnessed the ceremony, were
# fully answered in the perfect happiness of the union.
#
# AUSTEN - sense_and_sensibility
# FIRST: The family of Dashwood had long been settled in Sussex. Their estate was large,
# and their residence was at Norland Park, in the centre of their property,
# where, for many generations, they had lived in so respectable a manner as to
# engage the general good opinion of their surrounding acquaintance. The late
# owner of this estate was a single man, who lived to a very advanced age, and
# who for many years of his life, had a constant companion and housekeeper in his
# sister. But her death, which happened ten years before his own, produced a
# great alteration in his home; for to supply her loss, he invited and received
# into his house the family of his nephew Mr. Henry Dashwood, the legal inheritor
# of the Norland estate, and the person to whom he intended to bequeath it. In
# the society of his nephew and niece, and their children, the old
# Gentleman’s days were comfortably spent. His attachment to them all
# increased. The constant attention of Mr. and Mrs. Henry Dashwood to his wishes,
# which proceeded not merely from interest, but from goodness of heart, gave him
# every degree of solid comfort which his age could receive; and the cheerfulness
# of the children added a relish to his existence.
# LAST : Between Barton and Delaford, there was that constant communication which strong
# family affection would naturally dictate; and among the merits and the
# happiness of Elinor and Marianne, let it not be ranked as the least
# considerable, that though sisters, and living almost within sight of each
# other, they could live without disagreement between themselves, or producing
# coolness between their husbands.
#
# GASKELL - cranford
# FIRST: In the first place, Cranford is in possession of the Amazons; all the holders
# of houses above a certain rent are women. If a married couple come to settle in
# the town, somehow the gentleman disappears; he is either fairly frightened to
# death by being the only man in the Cranford evening parties, or he is accounted
# for by being with his regiment, his ship, or closely engaged in business all
# the week in the great neighbouring commercial town of Drumble, distant only
# twenty miles on a railroad. In short, whatever does become of the gentlemen,
# they are not at Cranford. What could they do if they were there? The surgeon
# has his round of thirty miles, and sleeps at Cranford; but every man cannot be
# a surgeon. For keeping the trim gardens full of choice flowers without a weed
# to speck them; for frightening away little boys who look wistfully at the said
# flowers through the railings; for rushing out at the geese that occasionally
# venture in to the gardens if the gates are left open; for deciding all
# questions of literature and politics without troubling themselves with
# unnecessary reasons or arguments; for obtaining clear and correct knowledge of
# everybody’s affairs in the parish; for keeping their neat maid-servants in
# admirable order; for kindness (somewhat dictatorial) to the poor, and real
# tender good offices to each other whenever they are in distress, the ladies of
# Cranford are quite sufficient. “A man,” as one of them observed to me once, “is so in the way in the house!” Although the ladies of Cranford know all
# each other’s proceedings, they are exceedingly indifferent to each other’s
# opinions. Indeed, as each has her own individuality, not to say eccentricity,
# pretty strongly developed, nothing is so easy as verbal retaliation; but,
# somehow, good-will reigns among them to a considerable degree.
# LAST : Ever since that day there has been the old friendly sociability in Cranford
# society; which I am thankful for, because of my dear Miss Matty’s love of peace
# and kindliness. We all love Miss Matty, and I somehow think we are all of us
# better when she is near us.
#
# GASKELL - mary_barton
# FIRST: Oh! 'tis hard, 'tis hard to be working The whole of the live-long day, When all the neighbours about one Are off to their jaunts and play. There's Richard he carries his baby, And Mary takes little Jane, And lovingly they'll be wandering Through field and briery lane.
# LAST : "They have. She has been couched, and can see as well as ever. She
# and Will are to be married on the twenty-fifth of this month, and
# he's bringing her out here next voyage; and Job Legh talks of coming
# too,—not to see you, Mary,—nor you, mother,—nor you, my little
# hero" (kissing him), "but to try and pick up a few specimens of
# Canadian insects, Will says. All the compliment is to the earwigs,
# you see, mother!"
#
# GASKELL - north_and_south
# FIRST: “ Edith !” said Margaret, gently, “Edith!”
# LAST : “Hush!” said Margaret, “or I shall try and show you your mother’s
# indignant tones as she says, ‘That woman!’ ”

# %% [markdown]
# ## Verify Consistency Across Books

# %% [markdown]
# Before proceeding, verifying that preprocessing didn't introduce artifacts. We check average sentence length across books by the same author to check that it should be roughly similar so that it is not a differentiating factor.

# %%
def avg_sentence_length(paragraphs):
    lengths = []
    for p in paragraphs:
        sentences = re.split(r"[.!?]", p)
        for s in sentences:
            if len(s.split()) > 3:
                lengths.append(len(s.split()))
    return np.mean(lengths)

for author in ["austen", "gaskell"]:
    vals = []
    for (a, b), paras in all_clean_data.items():
        if a == author:
            vals.append(avg_sentence_length(paras))
    print(author, "avg sentence length:", np.mean(vals))
# Out:
# austen avg sentence length: 19.674943900032964
# gaskell avg sentence length: 22.09862320992688

# %% [markdown]
# ## Re-chunk Into Fixed-Size Paragraphs
#
# Original paragraphs vary in length. We need consistent 100-200 word chunks for fair comparison.

# %%
def chunk_into_windows(paragraphs, min_words=100, max_words=200):
    chunks = []
    current = []

    for p in paragraphs:
        words = p.split()
        if len(current) + len(words) <= max_words:
            current.extend(words)
        else:
            if len(current) >= min_words:
                chunks.append(" ".join(current))
            current = words

    if len(current) >= min_words:
        chunks.append(" ".join(current))

    return chunks

# %% [markdown]
# ### Chunking Function
#
# Original paragraphs in novels vary wildly in length (some are 500+ words, others are 20 words).
#
# This function re-chunks all text into consistent 100-200 word windows while preserving sentence boundaries. This ensures:
# - Fair comparison across classes
# - Models can't use paragraph length as a shortcut
# - All samples have similar statistical properties

# %%
all_chunks = {}

for key, paras in all_clean_data.items():
    all_chunks[key] = chunk_into_windows(paras)
    print(key, len(all_chunks[key]))

print("\n--- SAMPLE CHUNKS ---\n")
for key, chunks in all_chunks.items():
    print(f"{key} - Total Chunks: {len(chunks)}")
    print("First Chunk:", chunks[0])
    print("Last Chunk :", chunks[-1])
    print()
# Out:
# ('austen', 'pride_and_prejudice') 621
# ('austen', 'emma') 806
# ('austen', 'sense_and_sensibility') 612
# ('gaskell', 'cranford') 323
# ('gaskell', 'mary_barton') 822
# ('gaskell', 'north_and_south') 870
#
# --- SAMPLE CHUNKS ---
#
# ('austen', 'pride_and_prejudice') - Total Chunks: 621
# First Chunk: It is a truth universally acknowledged, that a single man in possession of a good fortune must be in want of a wife. However little known the feelings or views of such a man may be on his first entering a neighbourhood, this truth is so well fixed in the minds of the surrounding families, that he is considered as the rightful property of some one or other of their daughters. “My dear Mr. Bennet,” said his lady to him one day, “have you heard that Netherfield Park is let at last? ” “But it is,” returned she; “for Mrs. Long has just been here, and she told me all about it.” “Do not you want to know who has taken it?” cried his wife, impatiently. “ You want to tell me, and I have no objection to hearing it.”
# Last Chunk : Lady Catherine was extremely indignant on the marriage of her nephew; and as she gave way to all the genuine frankness of her character, in her reply to the letter which announced its arrangement, she sent him language so very abusive, especially of Elizabeth, that for some time all intercourse was at an end. But at length, by Elizabeth’s persuasion, he was prevailed on to overlook the offence, and seek a reconciliation; and, after a little further resistance on the part of his aunt, her resentment gave way, either to her affection for him, or her curiosity to see how his wife conducted herself; and she condescended to wait on them at Pemberley, in spite of that pollution which its woods had received, not merely from the presence of such a mistress, but the visits of her uncle and aunt from the city. With the Gardiners they were always on the most intimate terms. Darcy, as well as Elizabeth, really loved them; and they were both ever sensible of the warmest gratitude towards the persons who, by bringing her into Derbyshire, had been the means of uniting them.
#
# ('austen', 'emma') - Total Chunks: 806
# First Chunk: Emma Woodhouse, handsome, clever, and rich, with a comfortable home and happy disposition, seemed to unite some of the best blessings of existence; and had lived nearly twenty-one years in the world with very little to distress or vex her. She was the youngest of the two daughters of a most affectionate, indulgent father; and had, in consequence of her sister’s marriage, been mistress of his house from a very early period. Her mother had died too long ago for her to have more than an indistinct remembrance of her caresses; and her place had been supplied by an excellent woman as governess, who had fallen little short of a mother in affection.
# Last Chunk : In this state of suspense they were befriended, not by any sudden illumination of Mr. Woodhouse’s mind, or any wonderful change of his nervous system, but by the operation of the same system in another way.—Mrs. Weston’s poultry-house was robbed one night of all her turkeys—evidently by the ingenuity of man. Other poultry-yards in the neighbourhood also suffered.—Pilfering was housebreaking to Mr. Woodhouse’s fears.—He was very uneasy; and but for the sense of his son-in-law’s protection, would have been under wretched alarm every night of his life. The strength, resolution, and presence of mind of the Mr. Knightleys, commanded his fullest dependence. While either of them protected him and his, Hartfield was safe.—But Mr. John Knightley must be in London again by the end of the first week in November. The result of this distress was, that, with a much more voluntary, cheerful consent than his daughter had ever presumed to hope for at the moment, she was able to fix her wedding-day—and Mr. Elton was called on, within a month from the marriage of Mr. and Mrs. Robert Martin, to join the hands of Mr. Knightley and Miss Woodhouse.
#
# ('austen', 'sense_and_sensibility') - Total Chunks: 612
# First Chunk: The family of Dashwood had long been settled in Sussex. Their estate was large, and their residence was at Norland Park, in the centre of their property, where, for many generations, they had lived in so respectable a manner as to engage the general good opinion of their surrounding acquaintance. The late owner of this estate was a single man, who lived to a very advanced age, and who for many years of his life, had a constant companion and housekeeper in his sister. But her death, which happened ten years before his own, produced a great alteration in his home; for to supply her loss, he invited and received into his house the family of his nephew Mr. Henry Dashwood, the legal inheritor of the Norland estate, and the person to whom he intended to bequeath it. In the society of his nephew and niece, and their children, the old Gentleman’s days were comfortably spent. His attachment to them all increased. The constant attention of Mr. and Mrs. Henry Dashwood to his wishes, which proceeded not merely from interest, but from goodness of heart, gave him every degree of solid comfort which his age could receive; and the cheerfulness of the children added a relish to his existence.
# Last Chunk : For Marianne, however, in spite of his incivility in surviving her loss, he always retained that decided regard which interested him in every thing that befell her, and made her his secret standard of perfection in woman; and many a rising beauty would be slighted by him in after-days as bearing no comparison with Mrs. Brandon. Mrs. Dashwood was prudent enough to remain at the cottage, without attempting a removal to Delaford; and fortunately for Sir John and Mrs. Jennings, when Marianne was taken from them, Margaret had reached an age highly suitable for dancing, and not very ineligible for being supposed to have a lover. Between Barton and Delaford, there was that constant communication which strong family affection would naturally dictate; and among the merits and the happiness of Elinor and Marianne, let it not be ranked as the least considerable, that though sisters, and living almost within sight of each other, they could live without disagreement between themselves, or producing coolness between their husbands.
#
# ('gaskell', 'cranford') - Total Chunks: 323
# First Chunk: In the first place, Cranford is in possession of the Amazons; all the holders of houses above a certain rent are women. If a married couple come to settle in the town, somehow the gentleman disappears; he is either fairly frightened to death by being the only man in the Cranford evening parties, or he is accounted for by being with his regiment, his ship, or closely engaged in business all the week in the great neighbouring commercial town of Drumble, distant only twenty miles on a railroad. In short, whatever does become of the gentlemen, they are not at Cranford. What could they do if they were there? The surgeon has his round of thirty miles, and sleeps at Cranford; but every man cannot be a surgeon. For keeping the trim gardens full of choice flowers without a weed to speck them; for frightening away little boys who look wistfully at the said flowers through the railings; for rushing out at the geese that occasionally venture in to the gardens if the gates are left open; for deciding all questions of literature and politics without troubling themselves with unnecessary reasons or arguments; for obtaining clear and correct knowledge of everybody’s affairs in the parish; for keeping their neat maid-servants in admirable order; for kindness (somewhat dictatorial) to the poor, and real tender good offices to each other whenever they are in distress, the ladies of Cranford are quite sufficient. “A man,” as one of them observed to me once, “is so in the way in the house!” Although the ladies of Cranford know all each other’s proceedings, they are exceedingly indifferent to each other’s opinions. Indeed, as each has her own individuality, not to say eccentricity, pretty strongly developed, nothing is so easy as verbal retaliation; but, somehow, good-will reigns among them to a considerable degree.
# Last Chunk : Mr Peter composed his countenance in a moment, and appeared shocked at the idea, which, as he said truly enough, was now presented to him for the first time; but then Mrs Jamieson must remember that he had been living for a long time among savages—all of whom were heathens—some of them, he was afraid, were downright Dissenters. Then, seeing Miss Matty draw near, he hastily changed the conversation, and after a little while, turning to me, he said, “Don’t be shocked, prim little Mary, at all my wonderful stories. I consider Mrs Jamieson fair game, and besides I am bent on propitiating her, and the first step towards it is keeping her well awake. I bribed her here by asking her to let me have her name as patroness for my poor conjuror this evening; and I don’t want to give her time enough to get up her rancour against the Hogginses, who are just coming in. I want everybody to be friends, for it harasses Matty so much to hear of these quarrels. I shall go at it again by-and-by, so you need not look shocked. I intend to enter the Assembly Room to-night with Mrs Jamieson on one side, and my lady, Mrs Hoggins, on the other. You see if I don’t.”
#
# ('gaskell', 'mary_barton') - Total Chunks: 822
# First Chunk: There are some fields near Manchester, well known to the inhabitants as "Green Heys Fields," through which runs a public footpath to a little village about two miles distant. In spite of these fields being flat and low, nay, in spite of the want of wood (the great and usual recommendation of level tracts of land), there is a charm about them which strikes even the inhabitant of a mountainous district, who sees and feels the effect of contrast in these common-place but thoroughly rural fields, with the busy, bustling manufacturing town he left but half-an-hour ago. Here and there an old black and white farm-house, with its rambling outbuildings, speaks of other times and other occupations than those which now absorb the population of the neighbourhood. Here in their seasons may be seen the country business of hay-making, ploughing, &c., which are such pleasant mysteries for townspeople to watch; and here the artisan, deafened with noise of tongues and engines, may come to listen awhile to the delicious sounds of rural life: the lowing of cattle, the milk-maids' call, the clatter and cackle of poultry in the old farm-yards. You cannot wonder, then, that these fields are popular places of resort at every holiday time; and you would not wonder, if you could see, or I properly describe, the charm of one particular stile, that it should be, on such occasions, a crowded halting-place. Close by it is a deep, clear pond, reflecting in its dark green depths the shadowy trees that bend over it to exclude the sun. The only place where its banks are shelving is on the side next to a rambling farm-yard, belonging to one of those old-world, gabled, black and white houses I named above, overlooking the field through which the public footpath leads. The porch of this farm-house is covered by a rose-tree; and the little garden surrounding it is crowded with a medley of old-fashioned herbs and flowers, planted long ago, when the garden was the only druggist's shop within reach, and allowed to grow in scrambling and wild luxuriance—roses, lavender, sage, balm (for tea), rosemary, pinks and wallflowers, onions and jessamine, in most republican and indiscriminate order. This farm-house and garden are within a hundred yards of the stile of which I spoke, leading from the large pasture field into a smaller one, divided by a hedge of hawthorn and black-thorn; and near this stile, on the further side, there runs a tale that primroses may often be found, and occasionally the blue sweet violet on the grassy hedge bank.
# Last Chunk : "Why, some good news. Come, give a guess what it is." "Then you give it up, do you? What do you say, mother?" "Not exactly,—but very near. The old woman has twice the spirit of the young one. Come, Mary, give a guess!" He covered his little boy's eyes with his hands for an instant, significantly, till the baby pushed them down, saying in his imperfect way, "They've done something to Margaret to give her back her sight!" exclaimed she. "They have. She has been couched, and can see as well as ever. She and Will are to be married on the twenty-fifth of this month, and he's bringing her out here next voyage; and Job Legh talks of coming too,—not to see you, Mary,—nor you, mother,—nor you, my little hero" (kissing him), "but to try and pick up a few specimens of Canadian insects, Will says. All the compliment is to the earwigs, you see, mother!"
#
# ('gaskell', 'north_and_south') - Total Chunks: 870
# First Chunk: But as Margaret half suspected, Edith had fallen asleep. She lay curled up on the sofa in the back drawing-room in Harley Street looking very lovely in her white muslin and blue ribbons. If Titania had ever been dressed in white muslin and blue ribbons, and had fallen asleep on a crimson damask sofa in a back drawing-room, Edith might have been taken for her. Margaret was struck afresh by her cousin’s beauty. They had grown up together from childhood, and all along Edith had been remarked upon by every one, except Margaret, for her prettiness; but Margaret had never thought about it until the last few days, when the prospect of soon losing her companion seemed to give force to every sweet quality and charm which Edith possessed. They had been talking about wedding dresses and wedding ceremonies; and Captain Lennox, and what he had told Edith about her future life at Corfu, where his regiment was stationed; and the difficulty of keeping a piano in good tune (a difficulty which Edith seemed to consider as one of the most formidable that could befall her in her married life), and what gowns she should want in the visits to Scotland, which would immediately succeed her marriage; but the whispered tone had latterly become more drowsy; and Margaret, after a pause of a few minutes, found, as she fancied, that in spite of the buzz in the next room, Edith had rolled herself up into a soft ball of muslin and ribbon, and silken curls, and gone off into a peaceful little after-dinner nap.
# Last Chunk : After a minute or two he gently disengaged her hands from her face, and laid her arms as they had once before been placed to protect him from the rioters. “Do you remember, love?” he murmured. “And how I requited you with my insolence the next day?” “Look here! Lift up your head. I have something to show you!” She slowly faced him, glowing with beautiful shame. “Do you know these roses?” he said, drawing out his pocket-book, in which were treasured up some dead flowers. “No!” she replied, with innocent curiosity. “Did I give them to you?” “No! Vanity; you did not. You may have worn sister roses very probably.” She looked at them, wondering for a minute, then she smiled a little as she said— “They are from Helstone, are they not? I know the deep indentations round the leaves. Oh! have you been there? When were you there?” “I wanted to see the place where Margaret grew to what she is, even at the worst time of all, when I had no hope of ever calling her mine. I went there on my return from Havre.”

# %% [markdown]
# ## Save Class 1 (Human Data)

# %%
human_data = []

for (author, book), chunks in all_chunks.items():
    for chunk in chunks:
        human_data.append({
            "text": chunk,
            "label": "human",
            "author": author,
            "source": book
        })

print("Total human paragraphs:", len(human_data))
print("Sample entry:\n", human_data[0])
# Out:
# Total human paragraphs: 4054
# Sample entry:
#  {'text': 'It is a truth universally acknowledged, that a single man in possession of a good fortune must be in want of a wife. However little known the feelings or views of such a man may be on his first entering a neighbourhood, this truth is so well fixed in the minds of the surrounding families, that he is considered as the rightful property of some one or other of their daughters. “My dear Mr. Bennet,” said his lady to him one day, “have you heard that Netherfield Park is let at last? ” “But it is,” returned she; “for Mrs. Long has just been here, and she told me all about it.” “Do not you want to know who has taken it?” cried his wife, impatiently. “ You want to tell me, and I have no objection to hearing it.”', 'label': 'human', 'author': 'austen', 'source': 'pride_and_prejudice'}

# %% [markdown]
# ### Apply Chunking
#
# This cell processes all the cleaned books and re-chunks them into 100-200 word windows.

# %%
import json

HUMAN_OUTPUT_FILE = "class1_human_data_try1.json"

with open(HUMAN_OUTPUT_FILE, "w", encoding="utf-8") as f:
    json.dump(human_data, f, indent=2, ensure_ascii=False)

print(f"Human data saved to {HUMAN_OUTPUT_FILE}")
# Out:
# Human data saved to class1_human_data_try1.json

# %% [markdown]
# ## Topic Extraction
#
# Need to identify 5-10 high-level topics that appear in both authors' work. These will be used to generate AI text on the same themes.

# %% [markdown]
# ### Approach
#
# Using a combination of personal reading experience and exploratory analysis (using online summaries, llms, etc.) to identify recurring themes across the six novels.

# %% [markdown]
# ### Final Topics (9 total)
#
# 1. Courtship and Marriage
# 2. Domestic Life and Family Obligation
# 3. Social Class and Reputation
# 4. Moral Judgment and Personal Character
# 5. Gender Roles and Social Constraint
# 6. Work, Industry, and Economic Struggle
# 7. Community, Gossip, and Social Networks
# 8. Individual Desire vs Social Expectation
# 9. Change, Mobility, and Social Reform

# %% [markdown]
# ### Design Choice: 9 Topics Overall vs Per-Book
#
# Since they talk about similar topics, instead of 5-10 topics per book, I decided to treat topics as **corpus-level semantic anchors** rather than book-specific labels.
#
# Reasoning:
# - Each novel naturally contributes content to multiple topics (e.g., both authors write about marriage, class, morality)
# - Treating topics at the corpus level prevents artificial inflation of topic categories
# - With 500 paragraphs per AI class and 9 topics, we get ~55 paragraphs per topic, which is sufficient for diversity
# - This approach ensures topics are actually comparable naturally across human and AI classes

# %% [markdown]
# ## API key setup

# %%
# API key setup (move to environment variable for production)
os.environ["GOOGLE_API_KEY"] = "AIzaSyC-yEM1oYrnRGRl31LhO1jUVPksDadQBk0"

client = genai.Client(api_key=os.environ["GOOGLE_API_KEY"])
MODEL_NAME = "models/gemma-3-27b-it"

# %%
from google import genai
import os

client = genai.Client(api_key=os.environ["GOOGLE_API_KEY"])

models = client.models.list()
for m in models:
    print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-exp-1206
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-2.5-flash-preview-09-2025
# models/gemini-2.5-flash-lite-preview-09-2025
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/deep-research-pro-preview-12-2025
# models/embedding-001
# models/text-embedding-004
# models/gemini-embedding-001
# models/aqa
# models/imagen-4.0-generate-preview-06-06
# models/imagen-4.0-ultra-generate-preview-06-06
# models/imagen-4.0-generate-001
# models/imagen-4.0-ultra-generate-001
# models/imagen-4.0-fast-generate-001
# models/veo-2.0-generate-001
# models/veo-3.0-generate-001
# models/veo-3.0-fast-generate-001
# models/veo-3.1-generate-preview
# models/veo-3.1-fast-generate-preview
# models/gemini-2.5-flash-native-audio-latest
# models/gemini-2.5-flash-native-audio-preview-09-2025
# models/gemini-2.5-flash-native-audio-preview-12-2025

# %% [markdown]
# ### Design Choice: Why Gemma?
#
# Using Gemini's Gemma model because:
# 1. **Free API access** - Found on Reddit that Gemma-3 has a largely unrestricted free tier (gemini-pro has stricter limits)
# 2. **Quality** - Gemma-3-27b-it produces coherent, diverse text
# 3. **Controllability** - Good response to temperature/top_p tuning
# 4. **Rate limits** - Can generate 500+ paragraphs without hitting quotas
#
# Alternative models like Gemini would work but require paid API access.

# %%
topics = [
    "Courtship and Marriage",
    "Domestic Life and Family Obligation",
    "Social Class and Reputation",
    "Moral Judgment and Personal Character",
    "Gender Roles and Social Constraint",
    "Work, Industry, and Economic Struggle",
    "Community, Gossip, and Social Networks",
    "Individual Desire versus Social Expectation",
    "Change, Mobility, and Social Reform"
]

TOTAL_PARAGRAPHS = 500
NUM_TOPICS = len(topics)

base_per_topic = TOTAL_PARAGRAPHS // NUM_TOPICS
remainder = TOTAL_PARAGRAPHS % NUM_TOPICS

print(f"Will generate ~{base_per_topic} paragraphs per topic")
# Out:
# Will generate ~55 paragraphs per topic

# %% [markdown]
# This cell sets up the topic list and calculates how many paragraphs to generate per topic.

# %% [markdown]
# ## Class 2: AI Text (Neutral Style)
#
# Generate 500 paragraphs on the same topics but with a neutral, contemporary voice. No style mimicry.

# %% [markdown]
# ### Diversity Strategy
#
# To avoid repetition, each paragraph uses:
# - A **topic** (e.g., "Courtship and Marriage")
# - A **lens** (e.g., psychological, economic, sociological)
# - A **constraint** (e.g., "Begin with a contrast between past and present")
#
# This creates varied prompts even within the same topic.

# %% [markdown]
# ### Why These Lenses and Constraints?
#
# The lens (perspective) + constraint (structural rule) combination serves two purposes:
#
# 1. **Diversity** - Prevents the model from generating repetitive text on the same topic
# 2. **Semantic variation** - Forces different angles on the same theme (e.g., marriage from psychological vs economic perspective)
#
# Note: **Gemma is deterministic**. It produces the same output for the same prompt. Without varying the lens and constraint, we'd get identical paragraphs for each topic. This combinatorial approach ensures every prompt is unique.
#
# This strategy is inspired by few-shot prompting but applied systematically across all generations.

# %%
topics = [
    "Courtship and Marriage",
    "Domestic Life and Family Obligation",
    "Social Class and Reputation",
    "Moral Judgment and Personal Character",
    "Gender Roles and Social Constraint",
    "Work, Industry, and Economic Struggle",
    "Community, Gossip, and Social Networks",
    "Individual Desire versus Social Expectation",
    "Change, Mobility, and Social Reform"
]

# %%
LENSES = [
    "a sociological perspective",
    "a psychological perspective",
    "an economic perspective",
    "an ethical or moral perspective",
    "an individual lived-experience perspective",
    "a community-level perspective",
    "a historical-comparative perspective",
    "an institutional or systemic perspective"
]

# %%
CONSTRAINTS = [
    "Begin by describing a specific everyday situation.",
    "Begin with a contrast between past and present.",
    "Begin by highlighting a tension or trade-off.",
    "Begin by describing an individual dilemma.",
    "Begin by describing a social norm or expectation.",
    "Begin by focusing on consequences rather than causes.",
    "Begin by describing a small, ordinary decision.",
    "Begin by outlining a common misunderstanding.",
    "Begin with a question that the paragraph then answers.",
    "Begin by describing a quiet or unnoticed moment."
]

# %% [markdown]
# ### Deduplication
#
# Track generated text to avoid duplicates given the deterministic nature.

# %%
seen_texts = set()

def is_duplicate(text):
    key = text.strip().lower()
    return key in seen_texts

def mark_seen(text):
    seen_texts.add(text.strip().lower())

# %%
assert "GOOGLE_API_KEY" in os.environ, "GOOGLE_API_KEY not set"

client = genai.Client(api_key=os.environ["GOOGLE_API_KEY"])

MODEL_NAME = "models/gemma-3-27b-it"

def call_gemma_api(prompt, max_retries=3):
    """
    Calls Gemma with high diversity settings.
    Retries on transient failures.
    """
    for attempt in range(max_retries):
        try:
            response = client.models.generate_content(
                model=MODEL_NAME,
                contents=prompt,
                config={
                    "temperature": 0.95,
                    "top_p": 0.9,
                    "top_k": 50,
                    "max_output_tokens": 450
                }
            )

            text = response.text.strip()

            if len(text.split()) < 80:
                raise ValueError("Output too short, retrying")

            return text

        except Exception as e:
            print(f"API error (attempt {attempt+1}/{max_retries}): {e}")
            time.sleep(2)

    return None

# %% [markdown]
# ### API Call Function
#
# This handles the actual generation with:
# - **High temperature (0.95)** - Encourages diverse outputs
# - **Retries** - Handles transient API failures
# - **Length check** - Ensures raw output is in the 100-200 word range.

# %%
def enforce_length(text, min_words=100, max_words=200):
    words = text.split()
    if len(words) < min_words:
        return None
    if len(words) > max_words:
        return " ".join(words[:max_words])
    return text

# %%
from itertools import product

ai_data = []
SEEN_TEXTS = set()
OUTPUT_FILE = "class2_ai_data_try1.json"

COMBINATIONS = list(product(LENSES, CONSTRAINTS))

def mark_seen(text):
    SEEN_TEXTS.add(text[:500])

def is_duplicate(text):
    return text[:500] in SEEN_TEXTS

# %% [markdown]
# ### Prompt Builder
#
# Creates a unique prompt for each paragraph by combining:
# - Topic (e.g., "Courtship and Marriage")
# - Lens (e.g., "psychological perspective")
# - Constraint (e.g., "Begin with a contrast")
# - Variation ID (for tracking in later analysis)

# %%
import uuid

def build_class2_prompt(topic, lens, constraint):
    variation_id = uuid.uuid4().hex[:8]

    prompt = f"""
You are generating original prose for a research dataset.

Topic:
"{topic}"

Perspective (MANDATORY):
Write from {lens}.

Structural constraint (MANDATORY):
{constraint}

Rules:
- Write ONE paragraph of 100–200 words
- Neutral, contemporary narrative voice
- No imitation of any author or literary period
- No archaic or Victorian language
- No dialogue unless unavoidable
- Avoid generic summaries
- Do not reuse phrasing or structure from previous responses

Variation ID: {variation_id}

Return only the paragraph text.
""".strip()

    return prompt, variation_id

# %% [markdown]
# ### Class 2 Generation Loop
#
# This is the main generation loop. Key features:
# - Iterates through all topics
# - Uses different lens/constraint combinations for each paragraph
# - Checks for duplicates using string prefix matching (first 500 chars)
# - Saves after each paragraph (safety against API failures)
# - Adds ~0.6s delay between calls (rate limiting)

# %%
for topic_idx, topic in enumerate(topics):
    n = base_per_topic + (1 if topic_idx < remainder else 0)
    generated_for_topic = 0
    attempts = 0
    combo_idx = topic_idx % len(COMBINATIONS)

    print(f"\nGenerating for topic: {topic} (target: {n} paragraphs)")

    while generated_for_topic < n:
        if combo_idx >= len(COMBINATIONS):
            print("Warning: Exhausted all lens-constraint combinations")
            break

        lens, constraint = COMBINATIONS[combo_idx]
        combo_idx += 1
        attempts += 1

        prompt, vid = build_class2_prompt(topic, lens, constraint)
        text = call_gemma_api(prompt)

        if not text:
            continue

        text = enforce_length(text)
        if text is None:
            continue

        if is_duplicate(text):
            continue

        mark_seen(text)

        ai_data.append({
            "text": text,
            "label": "ai",
            "topic": topic,
            "lens": lens,
            "constraint": constraint,
            "variation_id": vid
        })

        generated_for_topic += 1

        with open(OUTPUT_FILE, "w") as f:
            json.dump(ai_data, f, indent=2)

        print(f"{topic}: {generated_for_topic}/{n}")
        time.sleep(0.6)
# Out:
# Generating for topic: Courtship and Marriage (target: 56 paragraphs)
# Courtship and Marriage: 1/56
# Courtship and Marriage: 2/56
# Courtship and Marriage: 3/56
# Courtship and Marriage: 4/56
# Courtship and Marriage: 5/56
# Courtship and Marriage: 6/56
# Courtship and Marriage: 7/56
# Courtship and Marriage: 8/56
# Courtship and Marriage: 9/56
# Courtship and Marriage: 10/56
# Courtship and Marriage: 11/56
# Courtship and Marriage: 12/56
# Courtship and Marriage: 13/56
# Courtship and Marriage: 14/56
# Courtship and Marriage: 15/56
# Courtship and Marriage: 16/56
# Courtship and Marriage: 17/56
# Courtship and Marriage: 18/56
# Courtship and Marriage: 19/56
# Courtship and Marriage: 20/56
# Courtship and Marriage: 21/56
# Courtship and Marriage: 22/56
# Courtship and Marriage: 23/56
# Courtship and Marriage: 24/56
# Courtship and Marriage: 25/56
# Courtship and Marriage: 26/56
# Courtship and Marriage: 27/56
# Courtship and Marriage: 28/56
# Courtship and Marriage: 29/56
# Courtship and Marriage: 30/56
# Courtship and Marriage: 31/56
# Courtship and Marriage: 32/56
# Courtship and Marriage: 33/56
# Courtship and Marriage: 34/56
# Courtship and Marriage: 35/56
# Courtship and Marriage: 36/56
# Courtship and Marriage: 37/56
# API error (attempt 1/3): 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# Courtship and Marriage: 38/56
# Courtship and Marriage: 39/56
# Courtship and Marriage: 40/56
# Courtship and Marriage: 41/56
# Courtship and Marriage: 42/56
# Courtship and Marriage: 43/56
# Courtship and Marriage: 44/56
# Courtship and Marriage: 45/56
# Courtship and Marriage: 46/56
# Courtship and Marriage: 47/56
# Courtship and Marriage: 48/56
# Courtship and Marriage: 49/56
# Courtship and Marriage: 50/56
# Courtship and Marriage: 51/56
# Courtship and Marriage: 52/56
# Courtship and Marriage: 53/56
# Courtship and Marriage: 54/56
# Courtship and Marriage: 55/56
# Courtship and Marriage: 56/56
#
# Generating for topic: Domestic Life and Family Obligation (target: 56 paragraphs)
# Domestic Life and Family Obligation: 1/56
# Domestic Life and Family Obligation: 2/56
# Domestic Life and Family Obligation: 3/56
# Domestic Life and Family Obligation: 4/56
# Domestic Life and Family Obligation: 5/56
# Domestic Life and Family Obligation: 6/56
# Domestic Life and Family Obligation: 7/56
# Domestic Life and Family Obligation: 8/56
# Domestic Life and Family Obligation: 9/56
# Domestic Life and Family Obligation: 10/56
# Domestic Life and Family Obligation: 11/56
# Domestic Life and Family Obligation: 12/56
# Domestic Life and Family Obligation: 13/56
# Domestic Life and Family Obligation: 14/56
# Domestic Life and Family Obligation: 15/56
# Domestic Life and Family Obligation: 16/56
# Domestic Life and Family Obligation: 17/56
# Domestic Life and Family Obligation: 18/56
# Domestic Life and Family Obligation: 19/56
# Domestic Life and Family Obligation: 20/56
# Domestic Life and Family Obligation: 21/56
# Domestic Life and Family Obligation: 22/56
# Domestic Life and Family Obligation: 23/56
# Domestic Life and Family Obligation: 24/56
# Domestic Life and Family Obligation: 25/56
# Domestic Life and Family Obligation: 26/56
# Domestic Life and Family Obligation: 27/56
# Domestic Life and Family Obligation: 28/56
# Domestic Life and Family Obligation: 29/56
# Domestic Life and Family Obligation: 30/56
# Domestic Life and Family Obligation: 31/56
# Domestic Life and Family Obligation: 32/56
# Domestic Life and Family Obligation: 33/56
# Domestic Life and Family Obligation: 34/56
# Domestic Life and Family Obligation: 35/56
# Domestic Life and Family Obligation: 36/56
# Domestic Life and Family Obligation: 37/56
# Domestic Life and Family Obligation: 38/56
# Domestic Life and Family Obligation: 39/56
# Domestic Life and Family Obligation: 40/56
# Domestic Life and Family Obligation: 41/56
# Domestic Life and Family Obligation: 42/56
# Domestic Life and Family Obligation: 43/56
# Domestic Life and Family Obligation: 44/56
# Domestic Life and Family Obligation: 45/56
# Domestic Life and Family Obligation: 46/56
# Domestic Life and Family Obligation: 47/56
# Domestic Life and Family Obligation: 48/56
# Domestic Life and Family Obligation: 49/56
# Domestic Life and Family Obligation: 50/56
# Domestic Life and Family Obligation: 51/56
# Domestic Life and Family Obligation: 52/56
# Domestic Life and Family Obligation: 53/56
# Domestic Life and Family Obligation: 54/56
# Domestic Life and Family Obligation: 55/56
# Domestic Life and Family Obligation: 56/56
#
# Generating for topic: Social Class and Reputation (target: 56 paragraphs)
# Social Class and Reputation: 1/56
# Social Class and Reputation: 2/56
# Social Class and Reputation: 3/56
# Social Class and Reputation: 4/56
# Social Class and Reputation: 5/56
# Social Class and Reputation: 6/56
# Social Class and Reputation: 7/56
# Social Class and Reputation: 8/56
# Social Class and Reputation: 9/56
# Social Class and Reputation: 10/56
# Social Class and Reputation: 11/56
# Social Class and Reputation: 12/56
# Social Class and Reputation: 13/56
# Social Class and Reputation: 14/56
# Social Class and Reputation: 15/56
# Social Class and Reputation: 16/56
# Social Class and Reputation: 17/56
# Social Class and Reputation: 18/56
# Social Class and Reputation: 19/56
# Social Class and Reputation: 20/56
# Social Class and Reputation: 21/56
# Social Class and Reputation: 22/56
# Social Class and Reputation: 23/56
# Social Class and Reputation: 24/56
# Social Class and Reputation: 25/56
# Social Class and Reputation: 26/56
# Social Class and Reputation: 27/56
# Social Class and Reputation: 28/56
# Social Class and Reputation: 29/56
# Social Class and Reputation: 30/56
# Social Class and Reputation: 31/56
# Social Class and Reputation: 32/56
# Social Class and Reputation: 33/56
# Social Class and Reputation: 34/56
# Social Class and Reputation: 35/56
# Social Class and Reputation: 36/56
# Social Class and Reputation: 37/56
# Social Class and Reputation: 38/56
# Social Class and Reputation: 39/56
# Social Class and Reputation: 40/56
# Social Class and Reputation: 41/56
# Social Class and Reputation: 42/56
# Social Class and Reputation: 43/56
# Social Class and Reputation: 44/56
# Social Class and Reputation: 45/56
# Social Class and Reputation: 46/56
# Social Class and Reputation: 47/56
# Social Class and Reputation: 48/56
# Social Class and Reputation: 49/56
# Social Class and Reputation: 50/56
# Social Class and Reputation: 51/56
# Social Class and Reputation: 52/56
# Social Class and Reputation: 53/56
# Social Class and Reputation: 54/56
# Social Class and Reputation: 55/56
# Social Class and Reputation: 56/56
#
# Generating for topic: Moral Judgment and Personal Character (target: 56 paragraphs)
# Moral Judgment and Personal Character: 1/56
# Moral Judgment and Personal Character: 2/56
# Moral Judgment and Personal Character: 3/56
# Moral Judgment and Personal Character: 4/56
# Moral Judgment and Personal Character: 5/56
# Moral Judgment and Personal Character: 6/56
# Moral Judgment and Personal Character: 7/56
# Moral Judgment and Personal Character: 8/56
# Moral Judgment and Personal Character: 9/56
# Moral Judgment and Personal Character: 10/56
# Moral Judgment and Personal Character: 11/56
# Moral Judgment and Personal Character: 12/56
# Moral Judgment and Personal Character: 13/56
# Moral Judgment and Personal Character: 14/56
# Moral Judgment and Personal Character: 15/56
# API error (attempt 1/3): 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# Moral Judgment and Personal Character: 16/56
# Moral Judgment and Personal Character: 17/56
# Moral Judgment and Personal Character: 18/56
# Moral Judgment and Personal Character: 19/56
# Moral Judgment and Personal Character: 20/56
# Moral Judgment and Personal Character: 21/56
# Moral Judgment and Personal Character: 22/56
# Moral Judgment and Personal Character: 23/56
# Moral Judgment and Personal Character: 24/56
# Moral Judgment and Personal Character: 25/56
# Moral Judgment and Personal Character: 26/56
# Moral Judgment and Personal Character: 27/56
# Moral Judgment and Personal Character: 28/56
# Moral Judgment and Personal Character: 29/56
# Moral Judgment and Personal Character: 30/56
# Moral Judgment and Personal Character: 31/56
# Moral Judgment and Personal Character: 32/56
# Moral Judgment and Personal Character: 33/56
# Moral Judgment and Personal Character: 34/56
# Moral Judgment and Personal Character: 35/56
# Moral Judgment and Personal Character: 36/56
# Moral Judgment and Personal Character: 37/56
# Moral Judgment and Personal Character: 38/56
# Moral Judgment and Personal Character: 39/56
# Moral Judgment and Personal Character: 40/56
# Moral Judgment and Personal Character: 41/56
# Moral Judgment and Personal Character: 42/56
# Moral Judgment and Personal Character: 43/56
# Moral Judgment and Personal Character: 44/56
# Moral Judgment and Personal Character: 45/56
# Moral Judgment and Personal Character: 46/56
# Moral Judgment and Personal Character: 47/56
# Moral Judgment and Personal Character: 48/56
# Moral Judgment and Personal Character: 49/56
# Moral Judgment and Personal Character: 50/56
# Moral Judgment and Personal Character: 51/56
# Moral Judgment and Personal Character: 52/56
# Moral Judgment and Personal Character: 53/56
# Moral Judgment and Personal Character: 54/56
# Moral Judgment and Personal Character: 55/56
# Moral Judgment and Personal Character: 56/56
#
# Generating for topic: Gender Roles and Social Constraint (target: 56 paragraphs)
# Gender Roles and Social Constraint: 1/56
# Gender Roles and Social Constraint: 2/56
# Gender Roles and Social Constraint: 3/56
# Gender Roles and Social Constraint: 4/56
# Gender Roles and Social Constraint: 5/56
# Gender Roles and Social Constraint: 6/56
# Gender Roles and Social Constraint: 7/56
# Gender Roles and Social Constraint: 8/56
# Gender Roles and Social Constraint: 9/56
# Gender Roles and Social Constraint: 10/56
# Gender Roles and Social Constraint: 11/56
# Gender Roles and Social Constraint: 12/56
# Gender Roles and Social Constraint: 13/56
# Gender Roles and Social Constraint: 14/56
# Gender Roles and Social Constraint: 15/56
# Gender Roles and Social Constraint: 16/56
# Gender Roles and Social Constraint: 17/56
# Gender Roles and Social Constraint: 18/56
# Gender Roles and Social Constraint: 19/56
# Gender Roles and Social Constraint: 20/56
# Gender Roles and Social Constraint: 21/56
# Gender Roles and Social Constraint: 22/56
# Gender Roles and Social Constraint: 23/56
# Gender Roles and Social Constraint: 24/56
# Gender Roles and Social Constraint: 25/56
# Gender Roles and Social Constraint: 26/56
# Gender Roles and Social Constraint: 27/56
# Gender Roles and Social Constraint: 28/56
# Gender Roles and Social Constraint: 29/56
# Gender Roles and Social Constraint: 30/56
# Gender Roles and Social Constraint: 31/56
# Gender Roles and Social Constraint: 32/56
# Gender Roles and Social Constraint: 33/56
# Gender Roles and Social Constraint: 34/56
# Gender Roles and Social Constraint: 35/56
# Gender Roles and Social Constraint: 36/56
# Gender Roles and Social Constraint: 37/56
# Gender Roles and Social Constraint: 38/56
# Gender Roles and Social Constraint: 39/56
# Gender Roles and Social Constraint: 40/56
# Gender Roles and Social Constraint: 41/56
# Gender Roles and Social Constraint: 42/56
# Gender Roles and Social Constraint: 43/56
# Gender Roles and Social Constraint: 44/56
# API error (attempt 1/3): 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# Gender Roles and Social Constraint: 45/56
# Gender Roles and Social Constraint: 46/56
# Gender Roles and Social Constraint: 47/56
# Gender Roles and Social Constraint: 48/56
# Gender Roles and Social Constraint: 49/56
# Gender Roles and Social Constraint: 50/56
# Gender Roles and Social Constraint: 51/56
# Gender Roles and Social Constraint: 52/56
# Gender Roles and Social Constraint: 53/56
# Gender Roles and Social Constraint: 54/56
# Gender Roles and Social Constraint: 55/56
# Gender Roles and Social Constraint: 56/56
#
# Generating for topic: Work, Industry, and Economic Struggle (target: 55 paragraphs)
# Work, Industry, and Economic Struggle: 1/55
# Work, Industry, and Economic Struggle: 2/55
# Work, Industry, and Economic Struggle: 3/55
# Work, Industry, and Economic Struggle: 4/55
# Work, Industry, and Economic Struggle: 5/55
# Work, Industry, and Economic Struggle: 6/55
# Work, Industry, and Economic Struggle: 7/55
# Work, Industry, and Economic Struggle: 8/55
# Work, Industry, and Economic Struggle: 9/55
# Work, Industry, and Economic Struggle: 10/55
# Work, Industry, and Economic Struggle: 11/55
# API error (attempt 1/3): 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# Work, Industry, and Economic Struggle: 12/55
# Work, Industry, and Economic Struggle: 13/55
# Work, Industry, and Economic Struggle: 14/55
# Work, Industry, and Economic Struggle: 15/55
# Work, Industry, and Economic Struggle: 16/55
# Work, Industry, and Economic Struggle: 17/55
# Work, Industry, and Economic Struggle: 18/55
# Work, Industry, and Economic Struggle: 19/55
# Work, Industry, and Economic Struggle: 20/55
# Work, Industry, and Economic Struggle: 21/55
# Work, Industry, and Economic Struggle: 22/55
# Work, Industry, and Economic Struggle: 23/55
# API error (attempt 1/3): 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# API error (attempt 2/3): 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# Work, Industry, and Economic Struggle: 24/55
# Work, Industry, and Economic Struggle: 25/55
# Work, Industry, and Economic Struggle: 26/55
# Work, Industry, and Economic Struggle: 27/55
# Work, Industry, and Economic Struggle: 28/55
# Work, Industry, and Economic Struggle: 29/55
# Work, Industry, and Economic Struggle: 30/55
# API error (attempt 1/3): 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# API error (attempt 2/3): 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# Work, Industry, and Economic Struggle: 31/55
# Work, Industry, and Economic Struggle: 32/55
# Work, Industry, and Economic Struggle: 33/55
# Work, Industry, and Economic Struggle: 34/55
# API error (attempt 1/3): 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# Work, Industry, and Economic Struggle: 35/55
# Work, Industry, and Economic Struggle: 36/55
# Work, Industry, and Economic Struggle: 37/55
# Work, Industry, and Economic Struggle: 38/55
# Work, Industry, and Economic Struggle: 39/55
# Work, Industry, and Economic Struggle: 40/55
# Work, Industry, and Economic Struggle: 41/55
# Work, Industry, and Economic Struggle: 42/55
# Work, Industry, and Economic Struggle: 43/55
# Work, Industry, and Economic Struggle: 44/55
# Work, Industry, and Economic Struggle: 45/55
# API error (attempt 1/3): 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# Work, Industry, and Economic Struggle: 46/55
# Work, Industry, and Economic Struggle: 47/55
# Work, Industry, and Economic Struggle: 48/55
# Work, Industry, and Economic Struggle: 49/55
# Work, Industry, and Economic Struggle: 50/55
# Work, Industry, and Economic Struggle: 51/55
# Work, Industry, and Economic Struggle: 52/55
# Work, Industry, and Economic Struggle: 53/55
# Work, Industry, and Economic Struggle: 54/55
# Work, Industry, and Economic Struggle: 55/55
#
# Generating for topic: Community, Gossip, and Social Networks (target: 55 paragraphs)
# API error (attempt 1/3): 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# Community, Gossip, and Social Networks: 1/55
# Community, Gossip, and Social Networks: 2/55
# Community, Gossip, and Social Networks: 3/55
# Community, Gossip, and Social Networks: 4/55
# API error (attempt 1/3): 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# Community, Gossip, and Social Networks: 5/55
# Community, Gossip, and Social Networks: 6/55
# API error (attempt 1/3): 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# Community, Gossip, and Social Networks: 7/55
# Community, Gossip, and Social Networks: 8/55
# API error (attempt 1/3): 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# Community, Gossip, and Social Networks: 9/55
# Community, Gossip, and Social Networks: 10/55
# Community, Gossip, and Social Networks: 11/55
# API error (attempt 1/3): 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# Community, Gossip, and Social Networks: 12/55
# Community, Gossip, and Social Networks: 13/55
# Community, Gossip, and Social Networks: 14/55
# Community, Gossip, and Social Networks: 15/55
# Community, Gossip, and Social Networks: 16/55
# Community, Gossip, and Social Networks: 17/55
# Community, Gossip, and Social Networks: 18/55
# Community, Gossip, and Social Networks: 19/55
# Community, Gossip, and Social Networks: 20/55
# Community, Gossip, and Social Networks: 21/55
# Community, Gossip, and Social Networks: 22/55
# Community, Gossip, and Social Networks: 23/55
# Community, Gossip, and Social Networks: 24/55
# Community, Gossip, and Social Networks: 25/55
# Community, Gossip, and Social Networks: 26/55
# Community, Gossip, and Social Networks: 27/55
# Community, Gossip, and Social Networks: 28/55
# Community, Gossip, and Social Networks: 29/55
# Community, Gossip, and Social Networks: 30/55
# Community, Gossip, and Social Networks: 31/55
# Community, Gossip, and Social Networks: 32/55
# API error (attempt 1/3): 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# Community, Gossip, and Social Networks: 33/55
# Community, Gossip, and Social Networks: 34/55
# Community, Gossip, and Social Networks: 35/55
# Community, Gossip, and Social Networks: 36/55
# Community, Gossip, and Social Networks: 37/55
# Community, Gossip, and Social Networks: 38/55
# API error (attempt 1/3): 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# Community, Gossip, and Social Networks: 39/55
# Community, Gossip, and Social Networks: 40/55
# Community, Gossip, and Social Networks: 41/55
# Community, Gossip, and Social Networks: 42/55
# Community, Gossip, and Social Networks: 43/55
# Community, Gossip, and Social Networks: 44/55
# Community, Gossip, and Social Networks: 45/55
# Community, Gossip, and Social Networks: 46/55
# Community, Gossip, and Social Networks: 47/55
# Community, Gossip, and Social Networks: 48/55
# Community, Gossip, and Social Networks: 49/55
# Community, Gossip, and Social Networks: 50/55
# Community, Gossip, and Social Networks: 51/55
# Community, Gossip, and Social Networks: 52/55
# Community, Gossip, and Social Networks: 53/55
# Community, Gossip, and Social Networks: 54/55
# Community, Gossip, and Social Networks: 55/55
#
# Generating for topic: Individual Desire versus Social Expectation (target: 55 paragraphs)
# Individual Desire versus Social Expectation: 1/55
# Individual Desire versus Social Expectation: 2/55
# Individual Desire versus Social Expectation: 3/55
# Individual Desire versus Social Expectation: 4/55
# Individual Desire versus Social Expectation: 5/55
# Individual Desire versus Social Expectation: 6/55
# Individual Desire versus Social Expectation: 7/55
# Individual Desire versus Social Expectation: 8/55
# Individual Desire versus Social Expectation: 9/55
# Individual Desire versus Social Expectation: 10/55
# Individual Desire versus Social Expectation: 11/55
# Individual Desire versus Social Expectation: 12/55
# Individual Desire versus Social Expectation: 13/55
# Individual Desire versus Social Expectation: 14/55
# Individual Desire versus Social Expectation: 15/55
# Individual Desire versus Social Expectation: 16/55
# Individual Desire versus Social Expectation: 17/55
# Individual Desire versus Social Expectation: 18/55
# Individual Desire versus Social Expectation: 19/55
# Individual Desire versus Social Expectation: 20/55
# Individual Desire versus Social Expectation: 21/55
# Individual Desire versus Social Expectation: 22/55
# Individual Desire versus Social Expectation: 23/55
# Individual Desire versus Social Expectation: 24/55
# Individual Desire versus Social Expectation: 25/55
# Individual Desire versus Social Expectation: 26/55
# Individual Desire versus Social Expectation: 27/55
# Individual Desire versus Social Expectation: 28/55
# Individual Desire versus Social Expectation: 29/55
# Individual Desire versus Social Expectation: 30/55
# Individual Desire versus Social Expectation: 31/55
# Individual Desire versus Social Expectation: 32/55
# Individual Desire versus Social Expectation: 33/55
# Individual Desire versus Social Expectation: 34/55
# API error (attempt 1/3): 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# Individual Desire versus Social Expectation: 35/55
# Individual Desire versus Social Expectation: 36/55
# Individual Desire versus Social Expectation: 37/55
# Individual Desire versus Social Expectation: 38/55
# Individual Desire versus Social Expectation: 39/55
# Individual Desire versus Social Expectation: 40/55
# Individual Desire versus Social Expectation: 41/55
# Individual Desire versus Social Expectation: 42/55
# Individual Desire versus Social Expectation: 43/55
# Individual Desire versus Social Expectation: 44/55
# API error (attempt 1/3): 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# Individual Desire versus Social Expectation: 45/55
# API error (attempt 1/3): 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# API error (attempt 2/3): 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# API error (attempt 3/3): 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# Individual Desire versus Social Expectation: 46/55
# Individual Desire versus Social Expectation: 47/55
# API error (attempt 1/3): 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# Individual Desire versus Social Expectation: 48/55
# Individual Desire versus Social Expectation: 49/55
# Individual Desire versus Social Expectation: 50/55
# Individual Desire versus Social Expectation: 51/55
# Individual Desire versus Social Expectation: 52/55
# Individual Desire versus Social Expectation: 53/55
# Individual Desire versus Social Expectation: 54/55
# Individual Desire versus Social Expectation: 55/55
#
# Generating for topic: Change, Mobility, and Social Reform (target: 55 paragraphs)
# Change, Mobility, and Social Reform: 1/55
# Change, Mobility, and Social Reform: 2/55
# Change, Mobility, and Social Reform: 3/55
# Change, Mobility, and Social Reform: 4/55
# Change, Mobility, and Social Reform: 5/55
# Change, Mobility, and Social Reform: 6/55
# Change, Mobility, and Social Reform: 7/55
# Change, Mobility, and Social Reform: 8/55
# Change, Mobility, and Social Reform: 9/55
# Change, Mobility, and Social Reform: 10/55
# Change, Mobility, and Social Reform: 11/55
# Change, Mobility, and Social Reform: 12/55
# Change, Mobility, and Social Reform: 13/55
# Change, Mobility, and Social Reform: 14/55
# Change, Mobility, and Social Reform: 15/55
# Change, Mobility, and Social Reform: 16/55
# Change, Mobility, and Social Reform: 17/55
# Change, Mobility, and Social Reform: 18/55
# Change, Mobility, and Social Reform: 19/55
# Change, Mobility, and Social Reform: 20/55
# Change, Mobility, and Social Reform: 21/55

# %% [markdown]
# ## Class 3: AI Text (Style-Conditioned)
#
# Generate 500 paragraphs on the same topics, but conditioned to mimic Austen or Gaskell's style.
#
# Distribution:
# - 250 paragraphs in Austen's style
# - 250 paragraphs in Gaskell's style
#
# Author style guide generated again through a mix of human observed features and features describing the author on the internet and other resources

# %%
TOTAL_PARAGRAPHS = 500
AUTHORS = ["austen", "gaskell"]
PARAS_PER_AUTHOR = TOTAL_PARAGRAPHS // len(AUTHORS)  # 250 each

# %% [markdown]
# ### Style Guides
#
# These describe the authors' stylistic features at an abstract level:
# - Sentence patterns (e.g., Austen's periodic sentences)
# - Vocabulary preferences (e.g., Gaskell's industrial terms)
# - Punctuation habits (e.g., Austen's semicolons)
# - Narrative voice (e.g., Austen's irony vs Gaskell's emotional directness)
#
# The model uses these to condition generation without copying specific text.

# %%
AUTHOR_STYLE_GUIDES = {
    "austen": """
- Use syntactically complex but balanced sentences
- Employ indirect evaluation and mild irony
- Prefer formal, polite diction
- Embed moral judgment subtly within narration
- Avoid emotional excess or overt sentiment
""",
    "gaskell": """
- Use emotionally expressive but controlled language
- Emphasize social conditions and human impact
- Allow moral concern to be explicit
- Alternate between reflection and description
- Use grounded, socially aware narration
"""
}

# %% [markdown]
# ### Class 3 Setup and Helper Functions
#
# This cell sets up:
# - Deduplication using MD5 hashes (more robust than string matching)
# - Length enforcement (trim to 100-200 words)
# - Prompt builder that combines topic + author style + lens + constraint
#
# The hash-based deduplication normalizes text (lowercase, remove punctuation) before checking for duplicates.

# %%
import json
import time
import uuid
import re
import hashlib
from itertools import product

OUTPUT_FILE = "class3_ai_data_try1.json"

AUTHORS = ["austen", "gaskell"]
TOTAL_PARAGRAPHS = 500
PARAS_PER_AUTHOR = TOTAL_PARAGRAPHS // len(AUTHORS)

COMBINATIONS = list(product(LENSES, CONSTRAINTS))

ai_style_data = []
SEEN_HASHES = set()

def normalize_for_hash(text):
    text = text.lower()
    text = re.sub(r"\s+", " ", text)
    text = re.sub(r"[^\w\s]", "", text)
    return text.strip()

def is_duplicate(text):
    h = hashlib.md5(normalize_for_hash(text).encode()).hexdigest()
    return h in SEEN_HASHES

def mark_seen(text):
    h = hashlib.md5(normalize_for_hash(text).encode()).hexdigest()
    SEEN_HASHES.add(h)

def enforce_length(text, min_words=100, max_words=200):
    words = text.split()
    if len(words) < min_words:
        return None
    if len(words) > max_words:
        return " ".join(words[:max_words])
    return text
# Out:
# ==============================
#  Generating for AUSTEN (250)
# ==============================
#
# --- austen | Courtship and Marriage (28) ---
# [ austen | Courtship and Marriage ] 1/28
# [ austen | Courtship and Marriage ] 2/28
# [ austen | Courtship and Marriage ] 3/28
# [ austen | Courtship and Marriage ] 4/28
# [ austen | Courtship and Marriage ] 5/28
# [ austen | Courtship and Marriage ] 6/28
# [ austen | Courtship and Marriage ] 7/28
# [ austen | Courtship and Marriage ] 8/28
# [ austen | Courtship and Marriage ] 9/28
# [ austen | Courtship and Marriage ] 10/28
# [ austen | Courtship and Marriage ] 11/28
# [ austen | Courtship and Marriage ] 12/28
# [ austen | Courtship and Marriage ] 13/28
# [ austen | Courtship and Marriage ] 14/28
# [ austen | Courtship and Marriage ] 15/28
# [ austen | Courtship and Marriage ] 16/28
# [ austen | Courtship and Marriage ] 17/28
# [ austen | Courtship and Marriage ] 18/28
# [ austen | Courtship and Marriage ] 19/28
# [ austen | Courtship and Marriage ] 20/28
# [ austen | Courtship and Marriage ] 21/28
# [ austen | Courtship and Marriage ] 22/28
# [ austen | Courtship and Marriage ] 23/28
# [ austen | Courtship and Marriage ] 24/28
# [ austen | Courtship and Marriage ] 25/28
# [ austen | Courtship and Marriage ] 26/28
# [ austen | Courtship and Marriage ] 27/28
# [ austen | Courtship and Marriage ] 28/28
#
# --- austen | Domestic Life and Family Obligation (28) ---
# [ austen | Domestic Life and Family Obligation ] 1/28
# [ austen | Domestic Life and Family Obligation ] 2/28
# [ austen | Domestic Life and Family Obligation ] 3/28
# [ austen | Domestic Life and Family Obligation ] 4/28
# [ austen | Domestic Life and Family Obligation ] 5/28
# [ austen | Domestic Life and Family Obligation ] 6/28
# [ austen | Domestic Life and Family Obligation ] 7/28
# [ austen | Domestic Life and Family Obligation ] 8/28
# [ austen | Domestic Life and Family Obligation ] 9/28
# [ austen | Domestic Life and Family Obligation ] 10/28
# [ austen | Domestic Life and Family Obligation ] 11/28
# [ austen | Domestic Life and Family Obligation ] 12/28
# [ austen | Domestic Life and Family Obligation ] 13/28
# [ austen | Domestic Life and Family Obligation ] 14/28
# [ austen | Domestic Life and Family Obligation ] 15/28
# [ austen | Domestic Life and Family Obligation ] 16/28
# [ austen | Domestic Life and Family Obligation ] 17/28
# [ austen | Domestic Life and Family Obligation ] 18/28
# [ austen | Domestic Life and Family Obligation ] 19/28
# [ austen | Domestic Life and Family Obligation ] 20/28
# [ austen | Domestic Life and Family Obligation ] 21/28
# [ austen | Domestic Life and Family Obligation ] 22/28
# [ austen | Domestic Life and Family Obligation ] 23/28
# [ austen | Domestic Life and Family Obligation ] 24/28
# [ austen | Domestic Life and Family Obligation ] 25/28
# [ austen | Domestic Life and Family Obligation ] 26/28
# [ austen | Domestic Life and Family Obligation ] 27/28
# [ austen | Domestic Life and Family Obligation ] 28/28
#
# --- austen | Social Class and Reputation (28) ---
# [ austen | Social Class and Reputation ] 1/28
# [ austen | Social Class and Reputation ] 2/28
# [ austen | Social Class and Reputation ] 3/28
# [ austen | Social Class and Reputation ] 4/28
# [ austen | Social Class and Reputation ] 5/28
# [ austen | Social Class and Reputation ] 6/28
# [ austen | Social Class and Reputation ] 7/28
# [ austen | Social Class and Reputation ] 8/28
# [ austen | Social Class and Reputation ] 9/28
# [ austen | Social Class and Reputation ] 10/28
# [ austen | Social Class and Reputation ] 11/28
# [ austen | Social Class and Reputation ] 12/28
# [ austen | Social Class and Reputation ] 13/28
# [ austen | Social Class and Reputation ] 14/28
# [ austen | Social Class and Reputation ] 15/28
# [ austen | Social Class and Reputation ] 16/28
# [ austen | Social Class and Reputation ] 17/28
# [ austen | Social Class and Reputation ] 18/28
# [ austen | Social Class and Reputation ] 19/28
# [ austen | Social Class and Reputation ] 20/28
# [ austen | Social Class and Reputation ] 21/28
# [ austen | Social Class and Reputation ] 22/28
# [ austen | Social Class and Reputation ] 23/28
# [ austen | Social Class and Reputation ] 24/28
# [ austen | Social Class and Reputation ] 25/28
# [ austen | Social Class and Reputation ] 26/28
# [ austen | Social Class and Reputation ] 27/28
# ⚠️ Gemma error (attempt 1/3): 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# [ austen | Social Class and Reputation ] 28/28
#
# --- austen | Moral Judgment and Personal Character (28) ---
# [ austen | Moral Judgment and Personal Character ] 1/28
# [ austen | Moral Judgment and Personal Character ] 2/28
# [ austen | Moral Judgment and Personal Character ] 3/28
# [ austen | Moral Judgment and Personal Character ] 4/28
# [ austen | Moral Judgment and Personal Character ] 5/28
# [ austen | Moral Judgment and Personal Character ] 6/28
# [ austen | Moral Judgment and Personal Character ] 7/28
# [ austen | Moral Judgment and Personal Character ] 8/28
# [ austen | Moral Judgment and Personal Character ] 9/28
# [ austen | Moral Judgment and Personal Character ] 10/28
# [ austen | Moral Judgment and Personal Character ] 11/28
# [ austen | Moral Judgment and Personal Character ] 12/28
# [ austen | Moral Judgment and Personal Character ] 13/28
# [ austen | Moral Judgment and Personal Character ] 14/28
# [ austen | Moral Judgment and Personal Character ] 15/28
# [ austen | Moral Judgment and Personal Character ] 16/28
# [ austen | Moral Judgment and Personal Character ] 17/28
# [ austen | Moral Judgment and Personal Character ] 18/28
# [ austen | Moral Judgment and Personal Character ] 19/28
# [ austen | Moral Judgment and Personal Character ] 20/28
# [ austen | Moral Judgment and Personal Character ] 21/28
# [ austen | Moral Judgment and Personal Character ] 22/28
# [ austen | Moral Judgment and Personal Character ] 23/28
# [ austen | Moral Judgment and Personal Character ] 24/28
# [ austen | Moral Judgment and Personal Character ] 25/28
# [ austen | Moral Judgment and Personal Character ] 26/28
# [ austen | Moral Judgment and Personal Character ] 27/28
# [ austen | Moral Judgment and Personal Character ] 28/28
#
# --- austen | Gender Roles and Social Constraint (28) ---
# [ austen | Gender Roles and Social Constraint ] 1/28
# [ austen | Gender Roles and Social Constraint ] 2/28
# [ austen | Gender Roles and Social Constraint ] 3/28
# [ austen | Gender Roles and Social Constraint ] 4/28
# [ austen | Gender Roles and Social Constraint ] 5/28
# [ austen | Gender Roles and Social Constraint ] 6/28
# [ austen | Gender Roles and Social Constraint ] 7/28
# [ austen | Gender Roles and Social Constraint ] 8/28
# [ austen | Gender Roles and Social Constraint ] 9/28
# [ austen | Gender Roles and Social Constraint ] 10/28
# [ austen | Gender Roles and Social Constraint ] 11/28
# [ austen | Gender Roles and Social Constraint ] 12/28
# [ austen | Gender Roles and Social Constraint ] 13/28
# [ austen | Gender Roles and Social Constraint ] 14/28
# ⚠️ Gemma error (attempt 1/3): 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# [ austen | Gender Roles and Social Constraint ] 15/28
# [ austen | Gender Roles and Social Constraint ] 16/28
# [ austen | Gender Roles and Social Constraint ] 17/28
# [ austen | Gender Roles and Social Constraint ] 18/28
# [ austen | Gender Roles and Social Constraint ] 19/28
# [ austen | Gender Roles and Social Constraint ] 20/28
# [ austen | Gender Roles and Social Constraint ] 21/28
# [ austen | Gender Roles and Social Constraint ] 22/28
# [ austen | Gender Roles and Social Constraint ] 23/28
# [ austen | Gender Roles and Social Constraint ] 24/28
# [ austen | Gender Roles and Social Constraint ] 25/28
# [ austen | Gender Roles and Social Constraint ] 26/28
# [ austen | Gender Roles and Social Constraint ] 27/28
# [ austen | Gender Roles and Social Constraint ] 28/28
#
# --- austen | Work, Industry, and Economic Struggle (28) ---
# [ austen | Work, Industry, and Economic Struggle ] 1/28
# [ austen | Work, Industry, and Economic Struggle ] 2/28
# [ austen | Work, Industry, and Economic Struggle ] 3/28
# [ austen | Work, Industry, and Economic Struggle ] 4/28
# [ austen | Work, Industry, and Economic Struggle ] 5/28
# [ austen | Work, Industry, and Economic Struggle ] 6/28
# [ austen | Work, Industry, and Economic Struggle ] 7/28
# [ austen | Work, Industry, and Economic Struggle ] 8/28
# [ austen | Work, Industry, and Economic Struggle ] 9/28
# [ austen | Work, Industry, and Economic Struggle ] 10/28
# [ austen | Work, Industry, and Economic Struggle ] 11/28
# [ austen | Work, Industry, and Economic Struggle ] 12/28
# [ austen | Work, Industry, and Economic Struggle ] 13/28
# [ austen | Work, Industry, and Economic Struggle ] 14/28
# [ austen | Work, Industry, and Economic Struggle ] 15/28
# [ austen | Work, Industry, and Economic Struggle ] 16/28
# [ austen | Work, Industry, and Economic Struggle ] 17/28
# [ austen | Work, Industry, and Economic Struggle ] 18/28
# [ austen | Work, Industry, and Economic Struggle ] 19/28
# [ austen | Work, Industry, and Economic Struggle ] 20/28
# [ austen | Work, Industry, and Economic Struggle ] 21/28
# [ austen | Work, Industry, and Economic Struggle ] 22/28
# [ austen | Work, Industry, and Economic Struggle ] 23/28
# [ austen | Work, Industry, and Economic Struggle ] 24/28
# [ austen | Work, Industry, and Economic Struggle ] 25/28
# [ austen | Work, Industry, and Economic Struggle ] 26/28
# [ austen | Work, Industry, and Economic Struggle ] 27/28
# [ austen | Work, Industry, and Economic Struggle ] 28/28
#
# --- austen | Community, Gossip, and Social Networks (28) ---
# [ austen | Community, Gossip, and Social Networks ] 1/28
# [ austen | Community, Gossip, and Social Networks ] 2/28
# [ austen | Community, Gossip, and Social Networks ] 3/28
# [ austen | Community, Gossip, and Social Networks ] 4/28
# [ austen | Community, Gossip, and Social Networks ] 5/28
# [ austen | Community, Gossip, and Social Networks ] 6/28
# [ austen | Community, Gossip, and Social Networks ] 7/28
# [ austen | Community, Gossip, and Social Networks ] 8/28
# [ austen | Community, Gossip, and Social Networks ] 9/28
# [ austen | Community, Gossip, and Social Networks ] 10/28
# [ austen | Community, Gossip, and Social Networks ] 11/28
# [ austen | Community, Gossip, and Social Networks ] 12/28
# [ austen | Community, Gossip, and Social Networks ] 13/28
# [ austen | Community, Gossip, and Social Networks ] 14/28
# [ austen | Community, Gossip, and Social Networks ] 15/28
# [ austen | Community, Gossip, and Social Networks ] 16/28
# [ austen | Community, Gossip, and Social Networks ] 17/28
# [ austen | Community, Gossip, and Social Networks ] 18/28
# [ austen | Community, Gossip, and Social Networks ] 19/28
# [ austen | Community, Gossip, and Social Networks ] 20/28
# [ austen | Community, Gossip, and Social Networks ] 21/28
# [ austen | Community, Gossip, and Social Networks ] 22/28
# [ austen | Community, Gossip, and Social Networks ] 23/28
# [ austen | Community, Gossip, and Social Networks ] 24/28
# [ austen | Community, Gossip, and Social Networks ] 25/28
# [ austen | Community, Gossip, and Social Networks ] 26/28
# [ austen | Community, Gossip, and Social Networks ] 27/28
# [ austen | Community, Gossip, and Social Networks ] 28/28
#
# --- austen | Individual Desire versus Social Expectation (27) ---
# [ austen | Individual Desire versus Social Expectation ] 1/27
# [ austen | Individual Desire versus Social Expectation ] 2/27
# [ austen | Individual Desire versus Social Expectation ] 3/27
# [ austen | Individual Desire versus Social Expectation ] 4/27
# [ austen | Individual Desire versus Social Expectation ] 5/27
# [ austen | Individual Desire versus Social Expectation ] 6/27
# [ austen | Individual Desire versus Social Expectation ] 7/27
# [ austen | Individual Desire versus Social Expectation ] 8/27
# [ austen | Individual Desire versus Social Expectation ] 9/27
# [ austen | Individual Desire versus Social Expectation ] 10/27
# [ austen | Individual Desire versus Social Expectation ] 11/27
# [ austen | Individual Desire versus Social Expectation ] 12/27
# [ austen | Individual Desire versus Social Expectation ] 13/27
# [ austen | Individual Desire versus Social Expectation ] 14/27
# [ austen | Individual Desire versus Social Expectation ] 15/27
# [ austen | Individual Desire versus Social Expectation ] 16/27
# [ austen | Individual Desire versus Social Expectation ] 17/27
# [ austen | Individual Desire versus Social Expectation ] 18/27
# [ austen | Individual Desire versus Social Expectation ] 19/27
# [ austen | Individual Desire versus Social Expectation ] 20/27
# [ austen | Individual Desire versus Social Expectation ] 21/27
# [ austen | Individual Desire versus Social Expectation ] 22/27
# [ austen | Individual Desire versus Social Expectation ] 23/27
# [ austen | Individual Desire versus Social Expectation ] 24/27
# [ austen | Individual Desire versus Social Expectation ] 25/27
# [ austen | Individual Desire versus Social Expectation ] 26/27
# [ austen | Individual Desire versus Social Expectation ] 27/27
#
# --- austen | Change, Mobility, and Social Reform (27) ---
# [ austen | Change, Mobility, and Social Reform ] 1/27
# [ austen | Change, Mobility, and Social Reform ] 2/27
# [ austen | Change, Mobility, and Social Reform ] 3/27
# [ austen | Change, Mobility, and Social Reform ] 4/27
# [ austen | Change, Mobility, and Social Reform ] 5/27
# [ austen | Change, Mobility, and Social Reform ] 6/27
# [ austen | Change, Mobility, and Social Reform ] 7/27
# [ austen | Change, Mobility, and Social Reform ] 8/27
# [ austen | Change, Mobility, and Social Reform ] 9/27
# [ austen | Change, Mobility, and Social Reform ] 10/27
# [ austen | Change, Mobility, and Social Reform ] 11/27
# [ austen | Change, Mobility, and Social Reform ] 12/27
# [ austen | Change, Mobility, and Social Reform ] 13/27
# [ austen | Change, Mobility, and Social Reform ] 14/27
# [ austen | Change, Mobility, and Social Reform ] 15/27
# [ austen | Change, Mobility, and Social Reform ] 16/27
# [ austen | Change, Mobility, and Social Reform ] 17/27
# [ austen | Change, Mobility, and Social Reform ] 18/27
# [ austen | Change, Mobility, and Social Reform ] 19/27
# [ austen | Change, Mobility, and Social Reform ] 20/27
# [ austen | Change, Mobility, and Social Reform ] 21/27
# [ austen | Change, Mobility, and Social Reform ] 22/27
# [ austen | Change, Mobility, and Social Reform ] 23/27
# [ austen | Change, Mobility, and Social Reform ] 24/27
# [ austen | Change, Mobility, and Social Reform ] 25/27
# [ austen | Change, Mobility, and Social Reform ] 26/27
# [ austen | Change, Mobility, and Social Reform ] 27/27
#
# ==============================
#  Generating for GASKELL (250)
# ==============================
#
# --- gaskell | Courtship and Marriage (28) ---
# [ gaskell | Courtship and Marriage ] 1/28
# [ gaskell | Courtship and Marriage ] 2/28
# [ gaskell | Courtship and Marriage ] 3/28
# [ gaskell | Courtship and Marriage ] 4/28
# [ gaskell | Courtship and Marriage ] 5/28
# [ gaskell | Courtship and Marriage ] 6/28
# [ gaskell | Courtship and Marriage ] 7/28
# [ gaskell | Courtship and Marriage ] 8/28
# [ gaskell | Courtship and Marriage ] 9/28
# [ gaskell | Courtship and Marriage ] 10/28
# [ gaskell | Courtship and Marriage ] 11/28
# [ gaskell | Courtship and Marriage ] 12/28
# [ gaskell | Courtship and Marriage ] 13/28
# [ gaskell | Courtship and Marriage ] 14/28
# [ gaskell | Courtship and Marriage ] 15/28
# [ gaskell | Courtship and Marriage ] 16/28
# [ gaskell | Courtship and Marriage ] 17/28
# [ gaskell | Courtship and Marriage ] 18/28
# [ gaskell | Courtship and Marriage ] 19/28
# [ gaskell | Courtship and Marriage ] 20/28
# [ gaskell | Courtship and Marriage ] 21/28
# [ gaskell | Courtship and Marriage ] 22/28
# [ gaskell | Courtship and Marriage ] 23/28
# [ gaskell | Courtship and Marriage ] 24/28
# [ gaskell | Courtship and Marriage ] 25/28
# [ gaskell | Courtship and Marriage ] 26/28
# [ gaskell | Courtship and Marriage ] 27/28
# [ gaskell | Courtship and Marriage ] 28/28
#
# --- gaskell | Domestic Life and Family Obligation (28) ---
# [ gaskell | Domestic Life and Family Obligation ] 1/28
# [ gaskell | Domestic Life and Family Obligation ] 2/28
# [ gaskell | Domestic Life and Family Obligation ] 3/28
# [ gaskell | Domestic Life and Family Obligation ] 4/28
# [ gaskell | Domestic Life and Family Obligation ] 5/28
# [ gaskell | Domestic Life and Family Obligation ] 6/28
# [ gaskell | Domestic Life and Family Obligation ] 7/28
# [ gaskell | Domestic Life and Family Obligation ] 8/28
# [ gaskell | Domestic Life and Family Obligation ] 9/28
# [ gaskell | Domestic Life and Family Obligation ] 10/28
# [ gaskell | Domestic Life and Family Obligation ] 11/28
# [ gaskell | Domestic Life and Family Obligation ] 12/28
# [ gaskell | Domestic Life and Family Obligation ] 13/28
# [ gaskell | Domestic Life and Family Obligation ] 14/28
# [ gaskell | Domestic Life and Family Obligation ] 15/28
# [ gaskell | Domestic Life and Family Obligation ] 16/28
# [ gaskell | Domestic Life and Family Obligation ] 17/28
# [ gaskell | Domestic Life and Family Obligation ] 18/28
# [ gaskell | Domestic Life and Family Obligation ] 19/28
# [ gaskell | Domestic Life and Family Obligation ] 20/28
# [ gaskell | Domestic Life and Family Obligation ] 21/28
# [ gaskell | Domestic Life and Family Obligation ] 22/28
# [ gaskell | Domestic Life and Family Obligation ] 23/28
# [ gaskell | Domestic Life and Family Obligation ] 24/28
# [ gaskell | Domestic Life and Family Obligation ] 25/28
# [ gaskell | Domestic Life and Family Obligation ] 26/28
# [ gaskell | Domestic Life and Family Obligation ] 27/28
# [ gaskell | Domestic Life and Family Obligation ] 28/28
#
# --- gaskell | Social Class and Reputation (28) ---
# [ gaskell | Social Class and Reputation ] 1/28
# [ gaskell | Social Class and Reputation ] 2/28
# [ gaskell | Social Class and Reputation ] 3/28
# [ gaskell | Social Class and Reputation ] 4/28
# [ gaskell | Social Class and Reputation ] 5/28
# [ gaskell | Social Class and Reputation ] 6/28
# [ gaskell | Social Class and Reputation ] 7/28
# ⚠️ Gemma error (attempt 1/3): 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# [ gaskell | Social Class and Reputation ] 8/28
# [ gaskell | Social Class and Reputation ] 9/28
# [ gaskell | Social Class and Reputation ] 10/28
# [ gaskell | Social Class and Reputation ] 11/28
# [ gaskell | Social Class and Reputation ] 12/28
# [ gaskell | Social Class and Reputation ] 13/28
# [ gaskell | Social Class and Reputation ] 14/28
# [ gaskell | Social Class and Reputation ] 15/28
# [ gaskell | Social Class and Reputation ] 16/28
# [ gaskell | Social Class and Reputation ] 17/28
# [ gaskell | Social Class and Reputation ] 18/28
# [ gaskell | Social Class and Reputation ] 19/28
# [ gaskell | Social Class and Reputation ] 20/28
# [ gaskell | Social Class and Reputation ] 21/28
# [ gaskell | Social Class and Reputation ] 22/28
# [ gaskell | Social Class and Reputation ] 23/28
# [ gaskell | Social Class and Reputation ] 24/28
# [ gaskell | Social Class and Reputation ] 25/28
# [ gaskell | Social Class and Reputation ] 26/28
# [ gaskell | Social Class and Reputation ] 27/28
# [ gaskell | Social Class and Reputation ] 28/28
#
# --- gaskell | Moral Judgment and Personal Character (28) ---
# [ gaskell | Moral Judgment and Personal Character ] 1/28
# [ gaskell | Moral Judgment and Personal Character ] 2/28
# [ gaskell | Moral Judgment and Personal Character ] 3/28
# [ gaskell | Moral Judgment and Personal Character ] 4/28
# [ gaskell | Moral Judgment and Personal Character ] 5/28
# [ gaskell | Moral Judgment and Personal Character ] 6/28
# [ gaskell | Moral Judgment and Personal Character ] 7/28
# [ gaskell | Moral Judgment and Personal Character ] 8/28
# [ gaskell | Moral Judgment and Personal Character ] 9/28
# [ gaskell | Moral Judgment and Personal Character ] 10/28
# [ gaskell | Moral Judgment and Personal Character ] 11/28
# [ gaskell | Moral Judgment and Personal Character ] 12/28
# [ gaskell | Moral Judgment and Personal Character ] 13/28
# [ gaskell | Moral Judgment and Personal Character ] 14/28
# [ gaskell | Moral Judgment and Personal Character ] 15/28
# [ gaskell | Moral Judgment and Personal Character ] 16/28
# [ gaskell | Moral Judgment and Personal Character ] 17/28
# [ gaskell | Moral Judgment and Personal Character ] 18/28
# [ gaskell | Moral Judgment and Personal Character ] 19/28
# [ gaskell | Moral Judgment and Personal Character ] 20/28
# [ gaskell | Moral Judgment and Personal Character ] 21/28
# [ gaskell | Moral Judgment and Personal Character ] 22/28
# [ gaskell | Moral Judgment and Personal Character ] 23/28
# [ gaskell | Moral Judgment and Personal Character ] 24/28
# [ gaskell | Moral Judgment and Personal Character ] 25/28
# [ gaskell | Moral Judgment and Personal Character ] 26/28
# [ gaskell | Moral Judgment and Personal Character ] 27/28
# [ gaskell | Moral Judgment and Personal Character ] 28/28
#
# --- gaskell | Gender Roles and Social Constraint (28) ---
# [ gaskell | Gender Roles and Social Constraint ] 1/28
# [ gaskell | Gender Roles and Social Constraint ] 2/28
# [ gaskell | Gender Roles and Social Constraint ] 3/28
# [ gaskell | Gender Roles and Social Constraint ] 4/28
# [ gaskell | Gender Roles and Social Constraint ] 5/28
# [ gaskell | Gender Roles and Social Constraint ] 6/28
# [ gaskell | Gender Roles and Social Constraint ] 7/28
# ⚠️ Gemma error (attempt 1/3): 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# [ gaskell | Gender Roles and Social Constraint ] 8/28
# [ gaskell | Gender Roles and Social Constraint ] 9/28
# [ gaskell | Gender Roles and Social Constraint ] 10/28
# [ gaskell | Gender Roles and Social Constraint ] 11/28
# [ gaskell | Gender Roles and Social Constraint ] 12/28
# [ gaskell | Gender Roles and Social Constraint ] 13/28
# [ gaskell | Gender Roles and Social Constraint ] 14/28
# [ gaskell | Gender Roles and Social Constraint ] 15/28
# [ gaskell | Gender Roles and Social Constraint ] 16/28
# [ gaskell | Gender Roles and Social Constraint ] 17/28
# [ gaskell | Gender Roles and Social Constraint ] 18/28
# [ gaskell | Gender Roles and Social Constraint ] 19/28
# [ gaskell | Gender Roles and Social Constraint ] 20/28
# [ gaskell | Gender Roles and Social Constraint ] 21/28
# [ gaskell | Gender Roles and Social Constraint ] 22/28
# [ gaskell | Gender Roles and Social Constraint ] 23/28
# [ gaskell | Gender Roles and Social Constraint ] 24/28
# [ gaskell | Gender Roles and Social Constraint ] 25/28
# ⚠️ Gemma error (attempt 1/3): 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# ⚠️ Gemma error (attempt 2/3): 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# [ gaskell | Gender Roles and Social Constraint ] 26/28
# [ gaskell | Gender Roles and Social Constraint ] 27/28
# [ gaskell | Gender Roles and Social Constraint ] 28/28
#
# --- gaskell | Work, Industry, and Economic Struggle (28) ---
# [ gaskell | Work, Industry, and Economic Struggle ] 1/28
# [ gaskell | Work, Industry, and Economic Struggle ] 2/28
# [ gaskell | Work, Industry, and Economic Struggle ] 3/28
# [ gaskell | Work, Industry, and Economic Struggle ] 4/28
# [ gaskell | Work, Industry, and Economic Struggle ] 5/28
# [ gaskell | Work, Industry, and Economic Struggle ] 6/28
# [ gaskell | Work, Industry, and Economic Struggle ] 7/28
# [ gaskell | Work, Industry, and Economic Struggle ] 8/28
# [ gaskell | Work, Industry, and Economic Struggle ] 9/28
# [ gaskell | Work, Industry, and Economic Struggle ] 10/28
# [ gaskell | Work, Industry, and Economic Struggle ] 11/28
# [ gaskell | Work, Industry, and Economic Struggle ] 12/28
# [ gaskell | Work, Industry, and Economic Struggle ] 13/28
# [ gaskell | Work, Industry, and Economic Struggle ] 14/28
# [ gaskell | Work, Industry, and Economic Struggle ] 15/28
# [ gaskell | Work, Industry, and Economic Struggle ] 16/28
# [ gaskell | Work, Industry, and Economic Struggle ] 17/28
# [ gaskell | Work, Industry, and Economic Struggle ] 18/28
# [ gaskell | Work, Industry, and Economic Struggle ] 19/28
# [ gaskell | Work, Industry, and Economic Struggle ] 20/28
# [ gaskell | Work, Industry, and Economic Struggle ] 21/28
# [ gaskell | Work, Industry, and Economic Struggle ] 22/28
# [ gaskell | Work, Industry, and Economic Struggle ] 23/28
# [ gaskell | Work, Industry, and Economic Struggle ] 24/28
# [ gaskell | Work, Industry, and Economic Struggle ] 25/28
# [ gaskell | Work, Industry, and Economic Struggle ] 26/28
# [ gaskell | Work, Industry, and Economic Struggle ] 27/28
# [ gaskell | Work, Industry, and Economic Struggle ] 28/28
#
# --- gaskell | Community, Gossip, and Social Networks (28) ---
# [ gaskell | Community, Gossip, and Social Networks ] 1/28
# [ gaskell | Community, Gossip, and Social Networks ] 2/28
# [ gaskell | Community, Gossip, and Social Networks ] 3/28
# [ gaskell | Community, Gossip, and Social Networks ] 4/28
# [ gaskell | Community, Gossip, and Social Networks ] 5/28
# [ gaskell | Community, Gossip, and Social Networks ] 6/28
# [ gaskell | Community, Gossip, and Social Networks ] 7/28
# [ gaskell | Community, Gossip, and Social Networks ] 8/28
# [ gaskell | Community, Gossip, and Social Networks ] 9/28
# [ gaskell | Community, Gossip, and Social Networks ] 10/28
# [ gaskell | Community, Gossip, and Social Networks ] 11/28
# [ gaskell | Community, Gossip, and Social Networks ] 12/28
# [ gaskell | Community, Gossip, and Social Networks ] 13/28
# [ gaskell | Community, Gossip, and Social Networks ] 14/28
# [ gaskell | Community, Gossip, and Social Networks ] 15/28
# [ gaskell | Community, Gossip, and Social Networks ] 16/28
# [ gaskell | Community, Gossip, and Social Networks ] 17/28
# [ gaskell | Community, Gossip, and Social Networks ] 18/28
# [ gaskell | Community, Gossip, and Social Networks ] 19/28
# [ gaskell | Community, Gossip, and Social Networks ] 20/28
# [ gaskell | Community, Gossip, and Social Networks ] 21/28
# [ gaskell | Community, Gossip, and Social Networks ] 22/28
# [ gaskell | Community, Gossip, and Social Networks ] 23/28
# [ gaskell | Community, Gossip, and Social Networks ] 24/28
# [ gaskell | Community, Gossip, and Social Networks ] 25/28
# [ gaskell | Community, Gossip, and Social Networks ] 26/28
# [ gaskell | Community, Gossip, and Social Networks ] 27/28
# [ gaskell | Community, Gossip, and Social Networks ] 28/28
#
# --- gaskell | Individual Desire versus Social Expectation (27) ---
# [ gaskell | Individual Desire versus Social Expectation ] 1/27
# [ gaskell | Individual Desire versus Social Expectation ] 2/27
# [ gaskell | Individual Desire versus Social Expectation ] 3/27
# [ gaskell | Individual Desire versus Social Expectation ] 4/27
# [ gaskell | Individual Desire versus Social Expectation ] 5/27
# [ gaskell | Individual Desire versus Social Expectation ] 6/27
# [ gaskell | Individual Desire versus Social Expectation ] 7/27
# [ gaskell | Individual Desire versus Social Expectation ] 8/27
# [ gaskell | Individual Desire versus Social Expectation ] 9/27
# [ gaskell | Individual Desire versus Social Expectation ] 10/27
# [ gaskell | Individual Desire versus Social Expectation ] 11/27
# [ gaskell | Individual Desire versus Social Expectation ] 12/27
# [ gaskell | Individual Desire versus Social Expectation ] 13/27
# [ gaskell | Individual Desire versus Social Expectation ] 14/27
# [ gaskell | Individual Desire versus Social Expectation ] 15/27
# [ gaskell | Individual Desire versus Social Expectation ] 16/27
# [ gaskell | Individual Desire versus Social Expectation ] 17/27
# [ gaskell | Individual Desire versus Social Expectation ] 18/27
# [ gaskell | Individual Desire versus Social Expectation ] 19/27
# [ gaskell | Individual Desire versus Social Expectation ] 20/27
# [ gaskell | Individual Desire versus Social Expectation ] 21/27
# [ gaskell | Individual Desire versus Social Expectation ] 22/27
# [ gaskell | Individual Desire versus Social Expectation ] 23/27
# [ gaskell | Individual Desire versus Social Expectation ] 24/27
# [ gaskell | Individual Desire versus Social Expectation ] 25/27
# [ gaskell | Individual Desire versus Social Expectation ] 26/27
# [ gaskell | Individual Desire versus Social Expectation ] 27/27
#
# --- gaskell | Change, Mobility, and Social Reform (27) ---
# [ gaskell | Change, Mobility, and Social Reform ] 1/27
# [ gaskell | Change, Mobility, and Social Reform ] 2/27
# [ gaskell | Change, Mobility, and Social Reform ] 3/27
# [ gaskell | Change, Mobility, and Social Reform ] 4/27
# [ gaskell | Change, Mobility, and Social Reform ] 5/27
# [ gaskell | Change, Mobility, and Social Reform ] 6/27
# [ gaskell | Change, Mobility, and Social Reform ] 7/27
# [ gaskell | Change, Mobility, and Social Reform ] 8/27
# [ gaskell | Change, Mobility, and Social Reform ] 9/27
# [ gaskell | Change, Mobility, and Social Reform ] 10/27
# [ gaskell | Change, Mobility, and Social Reform ] 11/27
# [ gaskell | Change, Mobility, and Social Reform ] 12/27
# [ gaskell | Change, Mobility, and Social Reform ] 13/27
# [ gaskell | Change, Mobility, and Social Reform ] 14/27
# [ gaskell | Change, Mobility, and Social Reform ] 15/27
# [ gaskell | Change, Mobility, and Social Reform ] 16/27
# [ gaskell | Change, Mobility, and Social Reform ] 17/27
# [ gaskell | Change, Mobility, and Social Reform ] 18/27
# [ gaskell | Change, Mobility, and Social Reform ] 19/27
# [ gaskell | Change, Mobility, and Social Reform ] 20/27
# [ gaskell | Change, Mobility, and Social Reform ] 21/27
# [ gaskell | Change, Mobility, and Social Reform ] 22/27
# [ gaskell | Change, Mobility, and Social Reform ] 23/27
# [ gaskell | Change, Mobility, and Social Reform ] 24/27
# [ gaskell | Change, Mobility, and Social Reform ] 25/27
# [ gaskell | Change, Mobility, and Social Reform ] 26/27
# [ gaskell | Change, Mobility, and Social Reform ] 27/27
#
# ✅ Class 3 generation complete.
# Total paragraphs generated: 500

# %%
def build_class3_prompt(topic, author, lens, constraint):
    variation_id = uuid.uuid4().hex[:8]

    prompt = f"""
Write a single self-contained paragraph of 100–200 words on the topic:

"{topic}"

Write in a style inspired by {author}, following these stylistic tendencies:

{AUTHOR_STYLE_GUIDES[author]}

Additional constraints:
- {lens}
- {constraint}

Rules:
- Do not reference specific novels, characters, or places
- Do not quote or paraphrase existing text
- Maintain a continuous prose paragraph
- Emphasize sentence rhythm, clause structure, and narrative voice typical of this author
- Preserve topic content while expressing it through stylistic form

Variation ID: {variation_id}

Return only the paragraph text.
""".strip()

    return prompt, variation_id

# %% [markdown]
# ### Class 3 Generation Loop
#
# This is the main generation loop. Key features:
# - Iterates through all topics
# - Uses different lens/constraint combinations for each paragraph
# - Checks for duplicates using MD5 hashing (see setup cell above)
# - Saves after each paragraph (safety against API failures)
# - Adds ~0.6s delay between calls (rate limiting)

# %%
NUM_TOPICS = len(topics)
base_per_topic = PARAS_PER_AUTHOR // NUM_TOPICS
remainder = PARAS_PER_AUTHOR % NUM_TOPICS

for author in AUTHORS:

    author_count = 0
    print(f"\nGenerating for {author.upper()} (target: {PARAS_PER_AUTHOR} paragraphs)")

    for topic_idx, topic in enumerate(topics):

        n = base_per_topic + (1 if topic_idx < remainder else 0)
        generated_for_topic = 0
        combo_idx = (topic_idx + hash(author)) % len(COMBINATIONS)
        attempts = 0

        print(f"\n{author} - {topic} (target: {n})")

        while generated_for_topic < n:

            lens, constraint = COMBINATIONS[combo_idx % len(COMBINATIONS)]
            combo_idx += 1

            prompt, vid = build_class3_prompt(
                topic=topic,
                author=author,
                lens=lens,
                constraint=constraint
            )

            text = call_gemma_api(prompt)
            if not text:
                continue

            text = enforce_length(text)
            if text is None:
                continue

            if is_duplicate(text):
                continue

            mark_seen(text)

            ai_style_data.append({
                "text": text,
                "label": "ai",
                "author_style": author,
                "topic": topic,
                "lens": lens,
                "constraint": constraint,
                "variation_id": vid
            })

            generated_for_topic += 1

            with open(OUTPUT_FILE, "w") as f:
                json.dump(ai_style_data, f, indent=2)

            print(f"{author} - {topic}: {generated_for_topic}/{n}")
            time.sleep(0.6)


print("\nClass 3 generation complete.")
print(f"Total paragraphs generated: {len(ai_style_data)}")

# %% [markdown]
# ## Done
#
# Generated three datasets:
# - `class1_human_data_try1.json`: 500+ human paragraphs
# - `class2_ai_data_try1.json`: 500 AI paragraphs (neutral)
# - `class3_ai_data_try1.json`: 500 AI paragraphs (styled)
#
# All paragraphs are 100-200 words on the same 9 topics.

# %% [markdown]
# ### Dataset Summary
#
# **Class 1 (Human):**
# - Source: 6 novels (3 Austen + 3 Gaskell)
# - Processing: HTML cleaning, boilerplate removal, re-chunking
# - Output: ~4000+ paragraphs, 100-200 words each
#
# **Class 2 (AI-Neutral):**
# - Source: Gemini API (gemma-3-27b-it)
# - Strategy: Paragraph-level generation with lens/constraint diversity
# - Output: 500 paragraphs, 100-200 words each
#
# **Class 3 (AI-Styled):**
# - Source: Gemini API (gemma-3-27b-it)
# - Strategy: Style-conditioned generation (250 Austen-style, 250 Gaskell-style)
# - Output: 500 paragraphs, 100-200 words each
#
# All three classes share the same 9 topics, enabling fair comparison in downstream tasks.

# %% [markdown]
# ## Review of data
#
# After running the metrics of task 1 on this dataset, I decided that the created dataset was too weak and I would have to go through rounds of improving the generated dataset.
#
# I decided to have three variants (try1, try2, try3) so that it would allow us to compare:
# - **Paragraph-level generation** (this notebook) - More structured, explicit constraints
# - **Story-level generation** (try2) - More natural flow, organic variation
# - **Few-shot with examples** (try3) - Best style mimicry but risk of copying
#
# Tasks 1 & 2 will help us verify whether the dataset generation strategy has actually improved the dataset and does it become harder to detect.

# %% [markdown]
# ### Next: Try 2 - Story-Level Generation
#
# **Limitation of Try 1:**
# This notebook generates paragraphs independently with explicit lens/constraint combinations. While this ensures diversity, it may produce text that feels overly structured or artificially varied.
#
# **Try 2 Approach:**
# Instead of generating 500 isolated paragraphs, Try 2 will:
# 1. **Generate longer coherent stories** (1500-3000 words) on each topic
# 2. **Extract 100-200 word chunks** from these stories (like we did for human text)
# 3. **Leverage contextual flow** - paragraphs will have narrative continuity rather than being standalone
#
# **Why This Might Work Better:**
# - More natural variation within and between paragraphs
# - Mimics the actual structure of how human authors write (continuous narrative, not isolated thoughts)
# - Reduces the "template-like" quality that can emerge from structured prompts
# - Potentially harder for classifiers to detect since the generation process more closely resembles human writing
#
# **Trade-off:**
# Less explicit control over diversity (no lens/constraint combinations), but potentially more authentic stylistic variation through natural narrative flow.
